# %% [markdown]
# # Load the CSV data
#
# Load the data and do some exploring.
#
# Paper:
# https://www.nature.com/articles/s41597-022-01369-4

# %%
import pandas as pd

# %%
df = pd.read_csv('./cross-verified-database.csv', encoding='unicode_escape')

# %%
df.shape
# Out:
# (2291817, 49)

# %%
print(df.columns)
# Out:
# Index(['wikidata_code', 'birth', 'death', 'updated_death_date', 'approx_birth',
#        'approx_death', 'birth_min', 'birth_max', 'death_min', 'death_max',
#        'gender', 'level1_main_occ', 'name', 'un_subregion', 'birth_estimation',
#        'death_estimation', 'bigperiod_birth_graph_b',
#        'bigperiod_death_graph_b', 'curid', 'level2_main_occ', 'freq_main_occ',
#        'freq_second_occ', 'level2_second_occ', 'level3_main_occ',
#        'bigperiod_birth', 'bigperiod_death', 'wiki_readers_2015_2018',
#        'non_missing_score', 'total_count_words_b', 'number_wiki_editions',
#        'total_noccur_links_b', 'sum_visib_ln_5criteria',
#        'ranking_visib_5criteria', 'all_geography_groups',
#        'string_citizenship_raw_d', 'citizenship_1_b', 'citizenship_2_b',
#        'list_areas_of_rattach', 'area1_of_rattachment', 'area2_of_rattachment',
#        'list_wikipedia_editions', 'un_region', 'group_wikipedia_editions',
#        'bplo1', 'dplo1', 'bpla1', 'dpla1', 'pantheon_1', 'level3_all_occ'],
#       dtype='object')

# %%
person = df.loc[df['name'].str.contains('Su_Shi')]

# %%
person2 = df.loc[df['name'].str.contains('Liu_Cixin')]

# %%
print(person2)
# Out:
#         wikidata_code   birth  death  updated_death_date approx_birth  \
# 1833100       Q607588  1963.0    NaN                 NaN          NaN
#
#         approx_death  birth_min  birth_max  death_min  death_max  ...  \
# 1833100          NaN     1963.0     1963.0        NaN        NaN  ...
#
#         area2_of_rattachment  \
# 1833100              Missing
#
#                                    list_wikipedia_editions un_region  \
# 1833100  zhwiki|enwiki|eswiki|frwiki|jawiki|ruwiki|itwi...      Asia
#
#         group_wikipedia_editions       bplo1  dplo1     bpla1 dpla1  \
# 1833100                      grA  116.407524    NaN  39.90403   NaN
#
#          pantheon_1                                     level3_all_occ
# 1833100           0  D:_writer_writer_P:_science_writer_literary_En...
#
# [1 rows x 49 columns]

# %%
print(person)
# Out:
#         wikidata_code   birth   death  updated_death_date approx_birth  \
# 1220507        Q36020  1037.0  1101.0                 NaN          NaN
# 2228792      Q8292372  1950.0     NaN                 NaN          NaN
#
#         approx_death  birth_min  birth_max  death_min  death_max  ...  \
# 1220507          NaN     1037.0     1037.0     1101.0     1101.0  ...
# 2228792          NaN     1950.0     1950.0        NaN        NaN  ...
#
#         area2_of_rattachment  \
# 1220507              Missing
# 2228792              Missing
#
#                                    list_wikipedia_editions un_region  \
# 1220507  zh_min_nanwiki|zhwiki|jvwiki|bowiki|plwiki|frw...      Asia
# 2228792                        zhwiki|jawiki|enwiki|viwiki      Asia
#
#         group_wikipedia_editions       bplo1      dplo1      bpla1      dpla1  \
# 1220507                      grA  103.838058  119.96917  30.057461  31.812166
# 2228792                      grA  118.479721        NaN  36.696667        NaN
#
#          pantheon_1                                     level3_all_occ
# 1220507           0  D:_poet_writer_painter_pharmacist_P:_ writer_p...
# 2228792           0            D:_militar_P:_admiral_army_navy_English
#
# [2 rows x 49 columns]

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # How to convert CSV to database

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:891518@localhost:5432/notable_individuals')

# %%
df.to_sql('individuals', engine)
# Out:
# 817

# %% [markdown]
# # How to get the date of birth from Wikidata

# %%
from wikidata.client import Client

# %%
client = Client()

# %%
p1 = client.get("Q607588", load=True)

# %%
p1.description
# Out:
# m'Chinese science fiction writer'

# %%
p1.attributes
# Out:
# {'pageid': 572063,
#  'ns': 0,
#  'title': 'Q607588',
#  'lastrevid': 1995571970,
#  'modified': '2023-10-23T07:56:35Z',
#  'type': 'item',
#  'id': 'Q607588',
#  'labels': {'zh': {'language': 'zh', 'value': '刘慈欣'},
#   'en': {'language': 'en', 'value': 'Liu Cixin'},
#   'en-ca': {'language': 'en-ca', 'value': 'Liu Cixin'},
#   'en-gb': {'language': 'en-gb', 'value': 'Liu Cixin'},
#   'es': {'language': 'es', 'value': 'Liu Cixin'},
#   'fr': {'language': 'fr', 'value': 'Liu Cixin'},
#   'ja': {'language': 'ja', 'value': '劉慈欣'},
#   'zh-hans': {'language': 'zh-hans', 'value': '刘慈欣'},
#   'zh-hant': {'language': 'zh-hant', 'value': '劉慈欣'},
#   'zh-cn': {'language': 'zh-cn', 'value': '刘慈欣'},
#   'zh-sg': {'language': 'zh-sg', 'value': '刘慈欣'},
#   'zh-my': {'language': 'zh-my', 'value': '刘慈欣'},
#   'zh-hk': {'language': 'zh-hk', 'value': '劉慈欣'},
#   'zh-tw': {'language': 'zh-tw', 'value': '劉慈欣'},
#   'zh-mo': {'language': 'zh-mo', 'value': '劉慈欣'},
#   'nl': {'language': 'nl', 'value': 'Liu Cixin'},
#   'ru': {'language': 'ru', 'value': 'Лю Цысинь'},
#   'de': {'language': 'de', 'value': 'Liu Cixin'},
#   'it': {'language': 'it', 'value': 'Liu Cixin'},
#   'ko': {'language': 'ko', 'value': '류츠신'},
#   'hy': {'language': 'hy', 'value': 'Լյու Ցիսին'},
#   'uk': {'language': 'uk', 'value': 'Лю Цисінь'},
#   'fi': {'language': 'fi', 'value': 'Liu Cixin'},
#   'eo': {'language': 'eo', 'value': 'Liu Cixin'},
#   'pl': {'language': 'pl', 'value': 'Liu Cixin'},
#   'cs': {'language': 'cs', 'value': 'Liou Cch’-sin'},
#   'eu': {'language': 'eu', 'value': 'Liu Cixin'},
#   'id': {'language': 'id', 'value': 'Liu Cixin'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'Лю Цысінь'},
#   'ca': {'language': 'ca', 'value': 'Liu Cixin'},
#   'he': {'language': 'he', 'value': 'ליו צשין'},
#   'pt': {'language': 'pt', 'value': 'Liu Cixin'},
#   'ro': {'language': 'ro', 'value': 'Liu Cixin'},
#   'ga': {'language': 'ga', 'value': 'Liu Cixin'},
#   'gl': {'language': 'gl', 'value': 'Liu Cixin'},
#   'pt-br': {'language': 'pt-br', 'value': 'Liu Cixin'},
#   'ast': {'language': 'ast', 'value': 'Liu Cixin'},
#   'cy': {'language': 'cy', 'value': 'Liu Cixin'},
#   'af': {'language': 'af', 'value': 'Liu Cixin'},
#   'tr': {'language': 'tr', 'value': 'Liu Cixin'},
#   'ml': {'language': 'ml', 'value': 'ലിയു സിക്സിൻ'},
#   'fa': {'language': 'fa', 'value': 'لیو سیشین'},
#   'bg': {'language': 'bg', 'value': 'Лиу Цъсин'},
#   'sq': {'language': 'sq', 'value': 'Liu Cixin'},
#   'vi': {'language': 'vi', 'value': 'Lưu Từ Hân'},
#   'sv': {'language': 'sv', 'value': 'Liu Cixin'},
#   'hu': {'language': 'hu', 'value': 'Liu Ce-hszin'},
#   'ar': {'language': 'ar', 'value': 'ليو تسي شين'},
#   'arz': {'language': 'arz', 'value': 'ليو تسى شين'},
#   'et': {'language': 'et', 'value': 'Liu Cixin'},
#   'sr': {'language': 'sr', 'value': 'Љу Цисин'},
#   'nb': {'language': 'nb', 'value': 'Liu Cixin'},
#   'nn': {'language': 'nn', 'value': 'Liu Cixin'},
#   'wuu': {'language': 'wuu', 'value': '刘慈欣'},
#   'yue': {'language': 'yue', 'value': '劉慈欣'}},
#  'descriptions': {'zh': {'language': 'zh', 'value': '中国科幻作家'},
#   'zh-hans': {'language': 'zh-hans', 'value': '中国科幻作家'},
#   'zh-hant': {'language': 'zh-hant', 'value': '中國科幻作家'},
#   'zh-cn': {'language': 'zh-cn', 'value': '中国科幻作家'},
#   'zh-sg': {'language': 'zh-sg', 'value': '中国科幻作家'},
#   'zh-my': {'language': 'zh-my', 'value': '中国科幻作家'},
#   'zh-hk': {'language': 'zh-hk', 'value': '中國科幻作家'},
#   'zh-tw': {'language': 'zh-tw', 'value': '中國科幻作家'},
#   'zh-mo': {'language': 'zh-mo', 'value': '中國科幻作家'},
#   'en': {'language': 'en', 'value': 'Chinese science fiction writer'},
#   'nl': {'language': 'nl', 'value': 'Chinees schrijver'},
#   'it': {'language': 'it', 'value': 'scrittore cinese'},
#   'de': {'language': 'de', 'value': 'chinesischer Science-Fiction-Autor'},
#   'cs': {'language': 'cs', 'value': 'čínský spisovatel science fiction'},
#   'es': {'language': 'es', 'value': 'escritor de ciencia ficción chino'},
#   'fr': {'language': 'fr', 'value': 'auteur chinois'},
#   'uk': {'language': 'uk', 'value': 'китайський письменник-фантаст'},
#   'ga': {'language': 'ga', 'value': 'scríbhneoir ficsean crua-ealaíochta'},
#   'gl': {'language': 'gl', 'value': 'escritor chinés de ciencia ficción'},
#   'eo': {'language': 'eo', 'value': 'ĉina verkisto de sciencfikcio'},
#   'pl': {'language': 'pl', 'value': 'chiński pisarz science-fiction'},
#   'fi': {'language': 'fi', 'value': 'kiinalainen kirjailija'},
#   'ro': {'language': 'ro', 'value': 'scriitor chinez'},
#   'ca': {'language': 'ca', 'value': 'escriptor xinès de ciència ficció'},
#   'tr': {'language': 'tr', 'value': 'bilim kurgu yazarı'},
#   'bg': {'language': 'bg', 'value': 'китайски писател'},
#   'ru': {'language': 'ru', 'value': 'Китайский писатель-фантаст'},
#   'sv': {'language': 'sv', 'value': 'kinesisk science fiction-författare'},
#   'af': {'language': 'af', 'value': 'Chinese wetenskapfiksieskrywer'},
#   'arz': {'language': 'arz', 'value': 'كاتب خيال علمى من الصين'},
#   'ja': {'language': 'ja', 'value': '中華人民共和国の工学者、SF作家 (1963-)'},
#   'et': {'language': 'et', 'value': 'Hiina ulmekirjanik'},
#   'id': {'language': 'id', 'value': 'penulis fiksi ilmiah asal Tiongkok'}},
#  'aliases': {'en': [{'language': 'en', 'value': 'Cixin Liu'}],
#   'de': [{'language': 'de', 'value': 'Liú Cíxīn'},
#    {'language': 'de', 'value': 'Cixin Liu'}],
#   'cs': [{'language': 'cs', 'value': 'Liu Cixin'},
#    {'language': 'cs', 'value': "Liou Cch'-sin"},
#    {'language': 'cs', 'value': 'Liou Cch‘-Sin'}],
#   'ga': [{'language': 'ga', 'value': 'Cixin Liu'}],
#   'gl': [{'language': 'gl', 'value': 'Cixin Liu'}],
#   'zh': [{'language': 'zh', 'value': '劉慈欣'}],
#   'hu': [{'language': 'hu', 'value': 'Liu Cehszin'}],
#   'ja': [{'language': 'ja', 'value': 'りゅう じきん'},
#    {'language': 'ja', 'value': 'リウ・ツーシン'}],
#   'zh-hans': [{'language': 'zh-hans', 'value': '刘电工'},
#    {'language': 'zh-hans', 'value': '大刘'}]},
#  'claims': {'P244': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P244',
#      'hash': '51da504cf743eba171596f1de144cf420364581d',
#      'datavalue': {'value': 'n2005083742', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$C5BD39F3-F961-4FC2-9F57-648F1CE30F2D',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P214': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P214',
#      'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#      'datavalue': {'value': '78192675', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$A1668774-9F7C-490C-8322-3AAA1234E9A7',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P31': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P31',
#      'hash': 'ad7d38a03cdd40cdc373de0dc4e7b7fcbccb31d9',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 5,
#        'id': 'Q5'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$6F660C10-B6C9-409F-BF10-68EFDBCC5113',
#     'rank': 'normal',
#     'references': [{'hash': '0ee3b3ba1c958f4c3dcba7ed8091fe4b57311348',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'cb49f6fa327b245e4a5aaf48c44b3f503bcd4265',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 30239,
#            'id': 'Q30239'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P646': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P646',
#      'hash': '58a6c445060862b30e0aeed1fdcfe024fe4d4b35',
#      'datavalue': {'value': '/m/0g59dq6', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': '40bfcbb4484634ff9721ffdf48aae6c3f964c826',
#        'datavalue': {'value': 'Liu Cixin', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q607588$E4D16476-BBFD-43D8-835B-D1FF44D9E72D',
#     'rank': 'normal',
#     'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 15241312,
#            'id': 'Q15241312'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P577': [{'snaktype': 'value',
#          'property': 'P577',
#          'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#          'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P577']}]}],
#   'P734': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P734',
#      'hash': '6d4ab1aecb1d7eef0b816aa0b2dc9de1c306f20b',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 804970,
#        'id': 'Q804970'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$05E8CD80-7A6C-47BC-9968-C18066C40647',
#     'rank': 'normal'}],
#   'P19': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P19',
#      'hash': '7ff7a79ddf2566bd3fcc798f0d48466e256611ae',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 956,
#        'id': 'Q956'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$F039CAE9-6E84-4EFF-86BD-B95BD9CFC182',
#     'rank': 'normal',
#     'references': [{'hash': '1914606284eea383cdd6e8fa0304075a0c87fedf',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '19d24e3cc1ea94b0f7599e00e5246541eecec46d',
#          'datavalue': {'value': 'https://web.archive.org/web/20151017071744/http://www.chinadaily.com.cn/weekend/2015-10/17/content_22205909.htm',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]}],
#   'P21': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P21',
#      'hash': '85ad4b1c7348f7a5aac521135040d74e91fb5939',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 6581097,
#        'id': 'Q6581097'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$8758323A-8E36-4883-9720-9B8ECC21860B',
#     'rank': 'normal'}],
#   'P569': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P569',
#      'hash': 'c4f3037aef065af194c621b17be0681bd48ca308',
#      'datavalue': {'value': {'time': '+1963-06-23T00:00:00Z',
#        'timezone': 0,
#        'before': 0,
#        'after': 0,
#        'precision': 11,
#        'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#       'type': 'time'},
#      'datatype': 'time'},
#     'type': 'statement',
#     'id': 'Q607588$F5FF3112-722F-4522-A65F-58071639FA86',
#     'rank': 'normal',
#     'references': [{'hash': '993dcfb8a61533ae09546570a9f227e71455c2d9',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '871891c242389d06b23bf809fdc0301df1ed9c77',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 2629164,
#            'id': 'Q2629164'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P1233': [{'snaktype': 'value',
#          'property': 'P1233',
#          'hash': '5fdbda8e76060ac4343e9dfeec8e3d6a5659de97',
#          'datavalue': {'value': '208409', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P1810': [{'snaktype': 'value',
#          'property': 'P1810',
#          'hash': '0694b37af97172a4375f551840a362d7fea24317',
#          'datavalue': {'value': 'Cixin Liu', 'type': 'string'},
#          'datatype': 'string'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#          'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P1233', 'P1810', 'P813']},
#      {'hash': '0b87f7d3892d924d37a3c59dfb0e477954dbc0f2',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '9d66409d3d04632fc69413ea86abf094f92fae88',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3343389,
#            'id': 'Q3343389'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P5570': [{'snaktype': 'value',
#          'property': 'P5570',
#          'hash': '903ce5242125c3c6811c7acc7625b1fbc69c4802',
#          'datavalue': {'value': '2147199098', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P1810': [{'snaktype': 'value',
#          'property': 'P1810',
#          'hash': 'dc00eb40e2ffef4bd9ee0f92cbe9fe2afb2799f4',
#          'datavalue': {'value': 'Cixin LIU', 'type': 'string'},
#          'datatype': 'string'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#          'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P5570', 'P1810', 'P813']},
#      {'hash': '0af29df531a75add89dc8719524d0f42e59686ac',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '055f82ef73ce123450780d681359ac6e9077e315',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 107343683,
#            'id': 'Q107343683'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P1284': [{'snaktype': 'value',
#          'property': 'P1284',
#          'hash': '36a264839c7e6dd3ee70dafa46ef44cc8fbd4713',
#          'datavalue': {'value': '00000031303', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#          'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P1810': [{'snaktype': 'value',
#          'property': 'P1810',
#          'hash': '0694b37af97172a4375f551840a362d7fea24317',
#          'datavalue': {'value': 'Cixin Liu', 'type': 'string'},
#          'datatype': 'string'}]},
#       'snaks-order': ['P248', 'P1284', 'P813', 'P1810']}]}],
#   'P27': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P27',
#      'hash': '58336cfb8953436203b6809c7bff2f2cfd5dd412',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 148,
#        'id': 'Q148'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$E17729F4-B68A-4DCE-AE42-0FBBB29865DD',
#     'rank': 'normal'}],
#   'P1233': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1233',
#      'hash': '5fdbda8e76060ac4343e9dfeec8e3d6a5659de97',
#      'datavalue': {'value': '208409', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$dbe23be3-4a0b-d7c7-7a37-088e77117d3e',
#     'rank': 'normal'}],
#   'P213': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P213',
#      'hash': 'a5b8d0be795661853a27788fac30869724b070d2',
#      'datavalue': {'value': '0000 0000 3704 8121', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$DE89424B-EFD5-443D-8B3F-E3C796F4A8EC',
#     'rank': 'normal'}],
#   'P269': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P269',
#      'hash': '626cc43830198ad4c0bf410559d1f4fdb6a52dbd',
#      'datavalue': {'value': '176668667', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$E3818514-8ADB-41E0-B719-F12D8FCC270F',
#     'rank': 'normal'}],
#   'P227': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P227',
#      'hash': 'f0fa41a13277b0695af7077402a64f7c1ec4dc6c',
#      'datavalue': {'value': '1072055163', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$DAB335A3-3C76-408A-9D7A-BEDAA9C2E4DA',
#     'rank': 'normal',
#     'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 48183,
#            'id': 'Q48183'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P1412': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1412',
#      'hash': 'c4b2feea10e17b79fc63d43550841bd204e03a2c',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 7850,
#        'id': 'Q7850'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$4E906CA6-0209-4FA2-99CA-568E469823D5',
#     'rank': 'normal',
#     'references': [{'hash': 'd4bd87b862b12d99d26e86472d44f26858dee639',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'f30cbd35620c4ea6d0633aaf0210a8916130469b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 8447,
#            'id': 'Q8447'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']},
#      {'hash': '01d4887e35fbb03e409930200c08bf5cd71fba16',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '80047f9d5b0d2daf06989e71bd5f4ba15b215fd6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 13550863,
#            'id': 'Q13550863'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P691': [{'snaktype': 'value',
#          'property': 'P691',
#          'hash': '5c7b729a6c4cec940843cb6f397032c7bb11f7da',
#          'datavalue': {'value': 'xx0212744', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'b2ad08910940cafbe24537b40cf2cd06bef73cac',
#          'datavalue': {'value': {'time': '+2022-03-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P691', 'P813']}]}],
#   'P106': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '468425a7d5990169ca1caa25413280f78cb985f8',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 18844224,
#        'id': 'Q18844224'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$A40512D0-7D23-4E1C-9F7E-2228A30A3135',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': 'a4f30786546379e76f5e06bea1c90a99f3847ded',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 81096,
#        'id': 'Q81096'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P580': [{'snaktype': 'value',
#        'property': 'P580',
#        'hash': '3975d8bff9a27f2ccb7aeaea1348b4bc6c3de8b2',
#        'datavalue': {'value': {'time': '+1988-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}]},
#     'qualifiers-order': ['P580'],
#     'id': 'Q607588$E69A0FFA-2486-48C6-BF62-B7D94DBE633E',
#     'rank': 'normal',
#     'references': [{'hash': '14e2ee3158ee7e0d38b6a5c8c642beed2fd8973d',
#       'snaks': {'P3452': [{'snaktype': 'value',
#          'property': 'P3452',
#          'hash': '23052a33efe56f8f58cf279962ff58551747f009',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 7008700,
#            'id': 'Q7008700'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '4b4443c6cde48408607b2b14c27c923778e72417',
#          'datavalue': {'value': {'time': '+2019-06-20T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e17507043402fe54ae6c4d65cc51f46cec987de9',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 8449,
#            'id': 'Q8449'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P3452', 'P813', 'P143']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '70541c2eb72d85fa5f74008b4ee33b004a1ff7eb',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 36180,
#        'id': 'Q36180'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$b7e09133-d5e6-450e-891a-3566e189da94',
#     'rank': 'normal',
#     'references': [{'hash': '84eeea61f63a1aae6f9daf4dd727a65e330a69b1',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '80047f9d5b0d2daf06989e71bd5f4ba15b215fd6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 13550863,
#            'id': 'Q13550863'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P691': [{'snaktype': 'value',
#          'property': 'P691',
#          'hash': '5c7b729a6c4cec940843cb6f397032c7bb11f7da',
#          'datavalue': {'value': 'xx0212744', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'b4e48191d7758da9626aced312e5b843d129d93a',
#          'datavalue': {'value': {'time': '+2022-12-18T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P691', 'P813']}]}],
#   'P166': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P166',
#      'hash': '84e8f9abfeffe6308a299af8826d61c51016b550',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 255032,
#        'id': 'Q255032'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': 'b6849eb7f635c6ee36b75d8adf7e3f89c6624101',
#        'datavalue': {'value': {'time': '+2015-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P1686': [{'snaktype': 'value',
#        'property': 'P1686',
#        'hash': 'beccdf909c0b5f8f237b9c519e5c2179c97dde86',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 607112,
#          'id': 'Q607112'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P585', 'P1686'],
#     'id': 'Q607588$42938d6c-4e5e-694e-10a2-6a54e33a661a',
#     'rank': 'normal',
#     'references': [{'hash': '152b1d15d8566c102fe86b86293e3580d73732a9',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '51f7462379375042fbc3d78e47efb434cb7ee639',
#          'datavalue': {'value': 'http://www.thehugoawards.org/hugo-history/2015-hugo-awards/',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P166',
#      'hash': '6b9a7872b54c637ac1c026a171e5d166d875bcc5',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 2576795,
#        'id': 'Q2576795'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P1686': [{'snaktype': 'value',
#        'property': 'P1686',
#        'hash': '5d83710427b1f6c91ab1ed49b9f626ad4f673314',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 607511,
#          'id': 'Q607511'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}],
#      'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': 'c34a8cfb745b0cda47dffa6967839b8f92bcb653',
#        'datavalue': {'value': {'time': '+2017-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}]},
#     'qualifiers-order': ['P1686', 'P585'],
#     'id': 'Q607588$7d04d75c-4e58-26ed-28fc-3a975b31240d',
#     'rank': 'normal',
#     'references': [{'hash': '9ccf1201a15a9b55bbe48856c33aa0f930a1e964',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '1fd820bc0397e1390b50fc3ef894c8990a004ba1',
#          'datavalue': {'value': 'https://locusmag.com/2017/06/do-not-touch-2017-locus-awards-winners/',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P166',
#      'hash': '1590ab7365615e8037f083f1ff9bab1f64e18c76',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 6359432,
#        'id': 'Q6359432'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': 'c34a8cfb745b0cda47dffa6967839b8f92bcb653',
#        'datavalue': {'value': {'time': '+2017-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P1686': [{'snaktype': 'value',
#        'property': 'P1686',
#        'hash': 'beccdf909c0b5f8f237b9c519e5c2179c97dde86',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 607112,
#          'id': 'Q607112'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P585', 'P1686'],
#     'id': 'Q607588$6aa998cc-4199-5aa8-5e57-3d0e0d47caf1',
#     'rank': 'normal',
#     'references': [{'hash': '20e14043e41484501745a8367042e9fdd2433ed0',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'dff77fb78eecaf6d9ce4bb56bd77b46486c1e6ea',
#          'datavalue': {'value': 'http://www.aefcft.com/premios-ignotus-2017',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P166',
#      'hash': 'ccdd23169fe6c163c6c06c172c4158c983593dc7',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 27496509,
#        'id': 'Q27496509'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': '09f85c089438e099c1cd33998f5c59a57729afd2',
#        'datavalue': {'value': {'time': '+2020-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P1686': [{'snaktype': 'value',
#        'property': 'P1686',
#        'hash': 'beccdf909c0b5f8f237b9c519e5c2179c97dde86',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 607112,
#          'id': 'Q607112'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P585', 'P1686'],
#     'id': 'Q607588$ceddebcd-4acc-fd0e-dab9-753cd24fc622',
#     'rank': 'normal',
#     'references': [{'hash': '10b4186138dd64895c3f83021b5314849cb4a01f',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '48d3edf8da9585ccca4dd22c1c43fb80ebd57dfa',
#          'datavalue': {'value': 'http://www.sf-fan.gr.jp/awards/2020result.html',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P166',
#      'hash': 'ccdd23169fe6c163c6c06c172c4158c983593dc7',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 27496509,
#        'id': 'Q27496509'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': '4a6fe7f861358928efef462e361b21704446d129',
#        'datavalue': {'value': {'time': '+2021-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P1686': [{'snaktype': 'value',
#        'property': 'P1686',
#        'hash': '32c53deee2cd13207ea94c4e30a3ab9f032f3528',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 607276,
#          'id': 'Q607276'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P585', 'P1686'],
#     'id': 'Q607588$68e788a8-4c82-b454-d377-bc9f7a7e53a8',
#     'rank': 'normal',
#     'references': [{'hash': '77f96a0b34a2a602ce21282a88fa21d7f8526d58',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '7eb2f182cf8d710bd0bdc7f1256b4693cd1b8e2e',
#          'datavalue': {'value': 'http://www.sf-fan.gr.jp/awards/2021result.html',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]}],
#   'P434': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P434',
#      'hash': '20dae3db53e7e6713b9d55a40c760c0c73b32705',
#      'datavalue': {'value': '57f8a54d-521c-46f6-9340-c4f44096e203',
#       'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$8E511D97-581B-4924-A0CF-BF6626355CFC',
#     'rank': 'normal',
#     'references': [{'hash': '706208b3024200fd0a39ad499808dd0d98d74065',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '623cc8f0e2f65afe4d66b91962d354a2f3aa9a27',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 14005,
#            'id': 'Q14005'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P18': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P18',
#      'hash': '53e219647cabb1ca65eff4dec2a56cc4c373a380',
#      'datavalue': {'value': 'Geek Bar Tor authors event - Cixin Liu (18397919319).jpg',
#       'type': 'string'},
#      'datatype': 'commonsMedia'},
#     'type': 'statement',
#     'qualifiers': {'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': 'b6849eb7f635c6ee36b75d8adf7e3f89c6624101',
#        'datavalue': {'value': {'time': '+2015-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}]},
#     'qualifiers-order': ['P585'],
#     'id': 'Q607588$7b3f8385-402d-f7e8-91c0-2910c532d8da',
#     'rank': 'normal'}],
#   'P1559': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1559',
#      'hash': '74168bf344e5ac69a43aa7011ea2cb7abb153c79',
#      'datavalue': {'value': {'text': '刘慈欣', 'language': 'zh'},
#       'type': 'monolingualtext'},
#      'datatype': 'monolingualtext'},
#     'type': 'statement',
#     'id': 'Q607588$76413ac7-4067-efe5-6907-a0cab46f654c',
#     'rank': 'normal',
#     'references': [{'hash': '288ab581e7d2d02995a26dfa8b091d96e78457fc',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '6a164248fc96bfa583bbb495cb63ae6401ec203c',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 206855,
#            'id': 'Q206855'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P2002': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2002',
#      'hash': '4e30e44614c52b58c16e3c0686d3937450751245',
#      'datavalue': {'value': 'liu_cixin', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P3744': [{'snaktype': 'value',
#        'property': 'P3744',
#        'hash': '6e1cd0fb8964d0a5f7eeac0af7706b88fc80553c',
#        'datavalue': {'value': {'amount': '+7012', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'}],
#      'P6552': [{'snaktype': 'value',
#        'property': 'P6552',
#        'hash': 'dd60b0e4d6dd9359d11fbcb5173a8c5bfbd16fda',
#        'datavalue': {'value': '3454697657', 'type': 'string'},
#        'datatype': 'external-id'}],
#      'P580': [{'snaktype': 'value',
#        'property': 'P580',
#        'hash': 'd8ad0e49bd43068518f5914def1f993bcc0a5d7c',
#        'datavalue': {'value': {'time': '+2015-08-27T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 11,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': '56cc037272f9f69be746b8e68d238413c936dea5',
#        'datavalue': {'value': {'time': '+2020-04-22T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 11,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}]},
#     'qualifiers-order': ['P3744', 'P6552', 'P580', 'P585'],
#     'id': 'Q607588$ee28bfdc-4496-4c40-d92e-79821258a52b',
#     'rank': 'normal',
#     'references': [{'hash': '830e0d3d65e6b91e769889d7d1177706b5c1e0ca',
#       'snaks': {'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'cd8210fc3215a6112ebad72d11663d1a56b14d67',
#          'datavalue': {'value': {'time': '+2018-05-10T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P813']}]}],
#   'P2963': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2963',
#      'hash': '83e29c7a1b15f364ca905b74acabecc30b5e0010',
#      'datavalue': {'value': '5780686', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P585': [{'snaktype': 'value',
#        'property': 'P585',
#        'hash': '4742bd7d64eb60cd35c3e6f7f5fdafaf5fef1b30',
#        'datavalue': {'value': {'time': '+2020-09-28T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 11,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': '40bfcbb4484634ff9721ffdf48aae6c3f964c826',
#        'datavalue': {'value': 'Liu Cixin', 'type': 'string'},
#        'datatype': 'string'}],
#      'P3744': [{'snaktype': 'value',
#        'property': 'P3744',
#        'hash': 'b425e82c98e5d9a5ee52377e41cd376c80bb9eb4',
#        'datavalue': {'value': {'amount': '+6945', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'}]},
#     'qualifiers-order': ['P585', 'P1810', 'P3744'],
#     'id': 'Q607588$943bc874-4660-e6b8-266f-b6e923788b66',
#     'rank': 'normal'}],
#   'P1006': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1006',
#      'hash': '0b661304c643afa855dfadb49f082caca53ac53a',
#      'datavalue': {'value': '392806304', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$0880DA37-3DE4-4501-A942-BCF7629140FE',
#     'rank': 'normal',
#     'references': [{'hash': 'cceb53f4d5bff949516040bd3cb6d62443e2bad2',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'da1b1384faeda818862886998b5f5f89bce21628',
#          'datavalue': {'value': {'time': '+2018-04-07T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P813', 'P214']}]}],
#   'P5357': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P5357',
#      'hash': '6a8c15261ad14ff065f0f340d0a67974895df266',
#      'datavalue': {'value': 'liu_cixin', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$F2E12B44-C2EF-47B2-9F97-1D75939B8EF3',
#     'rank': 'normal',
#     'references': [{'hash': '00b7d4f210ff69bb1649f047576e8d6ebf124f61',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '5a343e7e758a4282a01316d3e959b6e653b767fc',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 11920,
#            'id': 'Q11920'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P4656': [{'snaktype': 'value',
#          'property': 'P4656',
#          'hash': '161c6f52c2ccc1f184e3a30b55c537d0aa3290f6',
#          'datavalue': {'value': 'https://it.wikipedia.org/w/index.php?title=Liu_Cixin&oldid=97431969',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P143', 'P4656']}]}],
#   'P5570': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P5570',
#      'hash': '903ce5242125c3c6811c7acc7625b1fbc69c4802',
#      'datavalue': {'value': '2147199098', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$88A9349F-1E55-4A06-BD51-DD3F5828F05B',
#     'rank': 'normal'}],
#   'P1280': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1280',
#      'hash': '250d717a93237df4d83ad1481741036992fdf616',
#      'datavalue': {'value': '295036003', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$7E660F18-43B6-4389-A167-4769B876DE3B',
#     'rank': 'normal'}],
#   'P691': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P691',
#      'hash': '5c7b729a6c4cec940843cb6f397032c7bb11f7da',
#      'datavalue': {'value': 'xx0212744', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$423DE312-EE2D-44AA-93EB-51570005E74E',
#     'rank': 'normal',
#     'references': [{'hash': 'fca2daaa1337b4bf8a23dfd935dbe2cdff66c921',
#       'snaks': {'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '6eed03d57f0a0348f81b20d1771dd891b5fc4ca1',
#          'datavalue': {'value': {'time': '+2018-12-15T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P214', 'P248', 'P813']}]}],
#   'P3553': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P3553',
#      'hash': '1b8f9780e70a80be6ac685b6f43b0c6494877693',
#      'datavalue': {'value': '19552213', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': '2e4e1025b7bcb2d79342f9a924c5713db3291fc7',
#        'datavalue': {'value': '刘慈欣（作家）', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q607588$d1ff12ad-4e3c-e17c-626d-003a45c396f2',
#     'rank': 'normal',
#     'references': [{'hash': 'e6a67002574b20ab920f78d4867baf4eafc230b8',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': 'aca85d4a51dd9e544adea9d2654cdb47e5da1664',
#          'datavalue': {'value': 'https://www.zhihu.com/search?q=%E5%88%98%E6%85%88%E6%AC%A3&type=content#刘慈欣「上班摸鱼」&刘慈欣在电厂上班时摸鱼写作',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5d1fc69c0b489dfa14f147b3ec77adf9b4307dbe',
#          'datavalue': {'value': {'time': '+2019-02-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P854', 'P813']}]}],
#   'P4862': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P4862',
#      'hash': '714d628efdaa8fdec7b469f098e9ab41555a8669',
#      'datavalue': {'value': 'B007JP96JU', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$14feb64a-473c-fac4-30b6-f4fc2b620fa4',
#     'rank': 'normal'}],
#   'P69': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P69',
#      'hash': 'c10f1fb3ad8c83a81aa0732812fb246e4869b9b6',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 10905490,
#        'id': 'Q10905490'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P580': [{'snaktype': 'value',
#        'property': 'P580',
#        'hash': '6c962b87b6da01d9d16bbf2bb0d7cbb3feaa5a0a',
#        'datavalue': {'value': {'time': '+1980-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 8,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P582': [{'snaktype': 'value',
#        'property': 'P582',
#        'hash': 'ce189cf09af7d69f8f2e97d114caa64b264ba30e',
#        'datavalue': {'value': {'time': '+1988-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}]},
#     'qualifiers-order': ['P580', 'P582'],
#     'id': 'Q607588$aae210f9-e495-460b-8b71-137da246a3b3',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P6441': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P6441',
#      'hash': '0c5f340542540d28e0cd586a5ef003e785a7abf8',
#      'datavalue': {'value': '4561353', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$f1e887f8-46e6-74e7-c729-835575e89f00',
#     'rank': 'normal'}],
#   'P800': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P800',
#      'hash': 'cdf29062429f2765f99af4316cb0661a848723d5',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 607112,
#        'id': 'Q607112'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$D5C6AC78-27E2-4A7F-A9B9-F78A0190A1E8',
#     'rank': 'normal',
#     'references': [{'hash': '12cc41612ec4aec3c99a16c000ac2c24f2038731',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P4656': [{'snaktype': 'value',
#          'property': 'P4656',
#          'hash': '46315cc80015081300e85fca278350b57a2e6f5a',
#          'datavalue': {'value': 'https://en.wikipedia.org/w/index.php?title=Liu_Cixin&oldid=890187445',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P143', 'P4656']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P800',
#      'hash': 'c3cae55c482328bbb028504b659d4f2e8449159e',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 607276,
#        'id': 'Q607276'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q607588$a5613256-4c0b-34e3-8920-3fedf04b46c5',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P800',
#      'hash': '647d10fec9bbbf682b7a3250ef95411d6f55052d',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 607511,
#        'id': 'Q607511'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
# ...
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$ed8c1109-408e-0a81-610d-443ca8792ff7',
#     'rank': 'normal',
#     'references': [{'hash': 'cd201337f120e1388d74d050ce8e7076261d4ef6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5347f50330c720277bc3d083bf442720604ae513',
#          'datavalue': {'value': {'time': '+2023-04-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P7699': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7699',
#      'hash': '070ff82f14bf24cec6c455c0060ad9a2c69ea716',
#      'datavalue': {'value': 'LNB:C+0W;=BA', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$b9991e1a-47ad-6946-26a7-a3b22c8535e3',
#     'rank': 'normal',
#     'references': [{'hash': 'cd201337f120e1388d74d050ce8e7076261d4ef6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5347f50330c720277bc3d083bf442720604ae513',
#          'datavalue': {'value': {'time': '+2023-04-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P1368': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1368',
#      'hash': '717e7e1825ac0557fbca7e21bc09430d0cf9030a',
#      'datavalue': {'value': '000251745', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$2531c3ae-49c9-e5c7-b9eb-1c5d1c660bb5',
#     'rank': 'normal',
#     'references': [{'hash': 'cd201337f120e1388d74d050ce8e7076261d4ef6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5347f50330c720277bc3d083bf442720604ae513',
#          'datavalue': {'value': {'time': '+2023-04-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P1375': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1375',
#      'hash': '1fd472854525dc548c99552957acc3e0018300b1',
#      'datavalue': {'value': '000680065', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$4950bb6d-492b-61a1-c475-f3b791e2aa12',
#     'rank': 'normal',
#     'references': [{'hash': 'cd201337f120e1388d74d050ce8e7076261d4ef6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5347f50330c720277bc3d083bf442720604ae513',
#          'datavalue': {'value': {'time': '+2023-04-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P1005': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1005',
#      'hash': 'c3a4877310604dcfad5ec50d080895389cae5b11',
#      'datavalue': {'value': '1814574', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$d9d8c0da-4d8f-d3a1-18bc-44d3fe54dea9',
#     'rank': 'normal',
#     'references': [{'hash': 'cd201337f120e1388d74d050ce8e7076261d4ef6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5347f50330c720277bc3d083bf442720604ae513',
#          'datavalue': {'value': {'time': '+2023-04-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P3065': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P3065',
#      'hash': 'b501ab06a7f4503e1f483d32d37907bd3744b998',
#      'datavalue': {'value': '02-A028222827', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q607588$bfd08361-4604-c79f-9b5a-101e8a213d5d',
#     'rank': 'normal',
#     'references': [{'hash': 'cd201337f120e1388d74d050ce8e7076261d4ef6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'acdafce73586aa5f16903042c79064348f3a79d3',
#          'datavalue': {'value': '78192675', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '5347f50330c720277bc3d083bf442720604ae513',
#          'datavalue': {'value': {'time': '+2023-04-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P345': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P345',
#      'hash': '2eb2fb332c61d9f13fae2c36674fabbdf0ead246',
#      'datavalue': {'value': 'nm7286732', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$6C295DD3-7A35-4841-892F-5A64D3CF580A',
#     'rank': 'normal'}],
#   'P4985': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P4985',
#      'hash': '5e41457599ebdf824f67209d3bffc33eba586a3e',
#      'datavalue': {'value': '1594537', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q607588$04B3FBF9-485E-4D7E-9267-CA4CCB7BA203',
#     'rank': 'normal'}]},
#  'sitelinks': {'afwiki': {'site': 'afwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://af.wikipedia.org/wiki/Liu_Cixin'},
#   'arwiki': {'site': 'arwiki',
#    'title': 'ليو تسي شين',
#    'badges': [],
#    'url': 'https://ar.wikipedia.org/wiki/%D9%84%D9%8A%D9%88_%D8%AA%D8%B3%D9%8A_%D8%B4%D9%8A%D9%86'},
#   'arzwiki': {'site': 'arzwiki',
#    'title': 'ليو تسى شين',
#    'badges': [],
#    'url': 'https://arz.wikipedia.org/wiki/%D9%84%D9%8A%D9%88_%D8%AA%D8%B3%D9%89_%D8%B4%D9%8A%D9%86'},
#   'astwiki': {'site': 'astwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://ast.wikipedia.org/wiki/Liu_Cixin'},
#   'be_x_oldwiki': {'site': 'be_x_oldwiki',
#    'title': 'Лю Цысінь',
#    'badges': [],
#    'url': 'https://be-tarask.wikipedia.org/wiki/%D0%9B%D1%8E_%D0%A6%D1%8B%D1%81%D1%96%D0%BD%D1%8C'},
#   'bgwiki': {'site': 'bgwiki',
#    'title': 'Лиу Цъсин',
#    'badges': [],
#    'url': 'https://bg.wikipedia.org/wiki/%D0%9B%D0%B8%D1%83_%D0%A6%D1%8A%D1%81%D0%B8%D0%BD'},
#   'bgwikiquote': {'site': 'bgwikiquote',
#    'title': 'Лиу Цъсин',
#    'badges': [],
#    'url': 'https://bg.wikiquote.org/wiki/%D0%9B%D0%B8%D1%83_%D0%A6%D1%8A%D1%81%D0%B8%D0%BD'},
#   'cawiki': {'site': 'cawiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://ca.wikipedia.org/wiki/Liu_Cixin'},
#   'commonswiki': {'site': 'commonswiki',
#    'title': 'Category:Liu Cixin',
#    'badges': [],
#    'url': 'https://commons.wikimedia.org/wiki/Category:Liu_Cixin'},
#   'cswiki': {'site': 'cswiki',
#    'title': 'Liou Cch’-sin',
#    'badges': [],
#    'url': 'https://cs.wikipedia.org/wiki/Liou_Cch%E2%80%99-sin'},
#   'dewiki': {'site': 'dewiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://de.wikipedia.org/wiki/Liu_Cixin'},
#   'enwiki': {'site': 'enwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://en.wikipedia.org/wiki/Liu_Cixin'},
#   'enwikiquote': {'site': 'enwikiquote',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://en.wikiquote.org/wiki/Liu_Cixin'},
#   'eowiki': {'site': 'eowiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://eo.wikipedia.org/wiki/Liu_Cixin'},
#   'eswiki': {'site': 'eswiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://es.wikipedia.org/wiki/Liu_Cixin'},
#   'etwikiquote': {'site': 'etwikiquote',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://et.wikiquote.org/wiki/Liu_Cixin'},
#   'euwiki': {'site': 'euwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://eu.wikipedia.org/wiki/Liu_Cixin'},
#   'fawiki': {'site': 'fawiki',
#    'title': 'لیو سیشین',
#    'badges': [],
#    'url': 'https://fa.wikipedia.org/wiki/%D9%84%DB%8C%D9%88_%D8%B3%DB%8C%D8%B4%DB%8C%D9%86'},
#   'fiwiki': {'site': 'fiwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://fi.wikipedia.org/wiki/Liu_Cixin'},
#   'frwiki': {'site': 'frwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://fr.wikipedia.org/wiki/Liu_Cixin'},
#   'frwikiquote': {'site': 'frwikiquote',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://fr.wikiquote.org/wiki/Liu_Cixin'},
#   'gawiki': {'site': 'gawiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://ga.wikipedia.org/wiki/Liu_Cixin'},
#   'glwiki': {'site': 'glwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://gl.wikipedia.org/wiki/Liu_Cixin'},
#   'hewiki': {'site': 'hewiki',
#    'title': 'ליו צשין',
#    'badges': [],
#    'url': 'https://he.wikipedia.org/wiki/%D7%9C%D7%99%D7%95_%D7%A6%D7%A9%D7%99%D7%9F'},
#   'huwiki': {'site': 'huwiki',
#    'title': 'Liu Ce-hszin',
#    'badges': [],
#    'url': 'https://hu.wikipedia.org/wiki/Liu_Ce-hszin'},
#   'hywiki': {'site': 'hywiki',
#    'title': 'Լյու Ցիսին',
#    'badges': [],
#    'url': 'https://hy.wikipedia.org/wiki/%D4%BC%D5%B5%D5%B8%D6%82_%D5%91%D5%AB%D5%BD%D5%AB%D5%B6'},
#   'idwiki': {'site': 'idwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://id.wikipedia.org/wiki/Liu_Cixin'},
#   'itwiki': {'site': 'itwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://it.wikipedia.org/wiki/Liu_Cixin'},
#   'itwikiquote': {'site': 'itwikiquote',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://it.wikiquote.org/wiki/Liu_Cixin'},
#   'jawiki': {'site': 'jawiki',
#    'title': '劉慈欣',
#    'badges': [],
#    'url': 'https://ja.wikipedia.org/wiki/%E5%8A%89%E6%85%88%E6%AC%A3'},
#   'kowiki': {'site': 'kowiki',
#    'title': '류츠신',
#    'badges': [],
#    'url': 'https://ko.wikipedia.org/wiki/%EB%A5%98%EC%B8%A0%EC%8B%A0'},
#   'mlwiki': {'site': 'mlwiki',
#    'title': 'ലിയു സിക്സിൻ',
#    'badges': [],
#    'url': 'https://ml.wikipedia.org/wiki/%E0%B4%B2%E0%B4%BF%E0%B4%AF%E0%B5%81_%E0%B4%B8%E0%B4%BF%E0%B4%95%E0%B5%8D%E0%B4%B8%E0%B4%BF%E0%B5%BB'},
#   'nlwiki': {'site': 'nlwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://nl.wikipedia.org/wiki/Liu_Cixin'},
#   'plwiki': {'site': 'plwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://pl.wikipedia.org/wiki/Liu_Cixin'},
#   'ptwiki': {'site': 'ptwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://pt.wikipedia.org/wiki/Liu_Cixin'},
#   'rowiki': {'site': 'rowiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://ro.wikipedia.org/wiki/Liu_Cixin'},
#   'ruwiki': {'site': 'ruwiki',
#    'title': 'Лю Цысинь',
#    'badges': [],
#    'url': 'https://ru.wikipedia.org/wiki/%D0%9B%D1%8E_%D0%A6%D1%8B%D1%81%D0%B8%D0%BD%D1%8C'},
#   'ruwikinews': {'site': 'ruwikinews',
#    'title': 'Категория:Лю Цысинь',
#    'badges': [],
#    'url': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%9B%D1%8E_%D0%A6%D1%8B%D1%81%D0%B8%D0%BD%D1%8C'},
#   'srwiki': {'site': 'srwiki',
#    'title': 'Љу Цисин',
#    'badges': [],
#    'url': 'https://sr.wikipedia.org/wiki/%D0%89%D1%83_%D0%A6%D0%B8%D1%81%D0%B8%D0%BD'},
#   'svwiki': {'site': 'svwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://sv.wikipedia.org/wiki/Liu_Cixin'},
#   'trwiki': {'site': 'trwiki',
#    'title': 'Liu Cixin',
#    'badges': [],
#    'url': 'https://tr.wikipedia.org/wiki/Liu_Cixin'},
#   'ukwiki': {'site': 'ukwiki',
#    'title': 'Лю Цисінь',
#    'badges': [],
#    'url': 'https://uk.wikipedia.org/wiki/%D0%9B%D1%8E_%D0%A6%D0%B8%D1%81%D1%96%D0%BD%D1%8C'},
#   'viwiki': {'site': 'viwiki',
#    'title': 'Lưu Từ Hân',
#    'badges': [],
#    'url': 'https://vi.wikipedia.org/wiki/L%C6%B0u_T%E1%BB%AB_H%C3%A2n'},
#   'wuuwiki': {'site': 'wuuwiki',
#    'title': '刘慈欣',
#    'badges': [],
#    'url': 'https://wuu.wikipedia.org/wiki/%E5%88%98%E6%85%88%E6%AC%A3'},
#   'zh_yuewiki': {'site': 'zh_yuewiki',
#    'title': '劉慈欣',
#    'badges': [],
#    'url': 'https://zh-yue.wikipedia.org/wiki/%E5%8A%89%E6%85%88%E6%AC%A3'},
#   'zhwiki': {'site': 'zhwiki',
#    'title': '刘慈欣',
#    'badges': [],
#    'url': 'https://zh.wikipedia.org/wiki/%E5%88%98%E6%85%88%E6%AC%A3'},
#   'zhwikiquote': {'site': 'zhwikiquote',
#    'title': '刘慈欣',
#    'badges': [],
#    'url': 'https://zh.wikiquote.org/wiki/%E5%88%98%E6%85%88%E6%AC%A3'}}}

# %% [markdown]
# We can see from the 'claims', that the date of birth is unter 'P569'.

# %%
attrs = [client.get(attribute) for attribute in  p1.attributes.get('claims').keys()]

# %%
date_of_birth = client.get('P569')

# %%
p1[date_of_birth]
# Out:
# datetime.date(1963, 6, 23)

# %% [markdown]
# # Add date of birth to test data

# %%
test_data = df.head(5)

# %%
test_data = test_data.copy(deep=True)

# %%
test_data['date_of_birth'] = ""

# %%
test_data
# Out:
#   wikidata_code   birth   death  updated_death_date approx_birth approx_death  \
# 0      Q1000002  1932.0  1990.0                 NaN          NaN          NaN
# 1      Q1000005  1860.0  1927.0                 NaN          NaN          NaN
# 2      Q1000006  1971.0     NaN                 NaN          NaN          NaN
# 3      Q1000015  1983.0     NaN                 NaN          NaN          NaN
# 4      Q1000023  1912.0  1977.0                 NaN          NaN          NaN
#
#    birth_min  birth_max  death_min  death_max  gender level1_main_occ  \
# 0     1932.0     1932.0     1990.0     1990.0    Male         Culture
# 1     1860.0     1860.0     1927.0     1927.0    Male         Culture
# 2     1971.0     1971.0        NaN        NaN    Male         Culture
# 3     1983.0     1983.0        NaN        NaN    Male         Culture
# 4     1912.0     1912.0     1977.0     1977.0  Female      Leadership
#
#                           name    un_subregion  birth_estimation  \
# 0                 Claus_Hammel  Western Europe            1932.0
# 1     Karel_MatÄj_Äapek-Chod  Western Europe            1860.0
# 2            Florian_Eichinger  Western Europe            1971.0
# 3                 Florian_Jahr  Western Europe            1983.0
# 4  Wiltraut_Rupp-von_BrÃ¼nneck  Western Europe            1912.0
#
#    death_estimation            bigperiod_birth_graph_b  \
# 0         1990.0000  5.Contemporary period 1901-2020AD
# 1         1927.0000    4.Mid Modern Period 1751-1900AD
# 2         2053.8447  5.Contemporary period 1901-2020AD
# 3         2067.1899  5.Contemporary period 1901-2020AD
# 4         1977.0000  5.Contemporary period 1901-2020AD
#
#              bigperiod_death_graph_b    curid     level2_main_occ  \
# 0  5.Contemporary period 1901-2020AD  2949539        Culture-core
# 1  5.Contemporary period 1901-2020AD  4217319        Culture-core
# 2  5.Contemporary period 1901-2020AD  5050967        Culture-core
# 3  5.Contemporary period 1901-2020AD  2588583        Culture-core
# 4  5.Contemporary period 1901-2020AD   922120  Administration/Law
#
#    freq_main_occ  freq_second_occ  level2_second_occ level3_main_occ  \
# 0       0.800000         0.200000  Culture-periphery      playwright
# 1       0.538462         0.307692  Culture-periphery          writer
# 2       1.000000              NaN            Missing            film
# 3       1.000000              NaN            Missing           actor
# 4       0.833333         0.166667           Politics           judge
#
#                      bigperiod_birth                    bigperiod_death  \
# 0  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 1    4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 2  5.Contemporary period 1901-2020AD                            Missing
# 3  5.Contemporary period 1901-2020AD                            Missing
# 4  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
#
#    wiki_readers_2015_2018  non_missing_score  total_count_words_b  \
# 0                    1669                  3                 1777
# 1                   25008                  3                 6491
# 2                   27285                  3                 1573
# 3                   37331                  3                 1931
# 4                    2955                  3                 1578
#
#    number_wiki_editions  total_noccur_links_b  sum_visib_ln_5criteria  \
# 0                     1                    11               18.083672
# 1                     9                    15               23.980610
# 2                     1                    10               20.666656
# 3                     1                    10               21.185040
# 4                     1                     6               17.996210
#
#    ranking_visib_5criteria all_geography_groups string_citizenship_raw_d  \
# 0                1058542.0              Germany                'Germany'
# 1                 131428.0       Czech_Republic         'Czech_Republic'
# 2                 775768.0              Germany                'Germany'
# 3                 691735.0              Germany                'Germany'
# 4                1103282.0              Germany                'Germany'
#
#   citizenship_1_b citizenship_2_b  \
# 0         Germany             NaN
# 1  Czech_Republic             NaN
# 2         Germany             NaN
# 3         Germany             NaN
# 4         Germany             NaN
#
#                                list_areas_of_rattach  \
# 0                  D:_'Germany'_matchB1_P:_'Germany'
# 1  D:_'Czech_Republic'_mismatchB2_P:_'Czech_Repub...
# 2                  D:_'Germany'_matchB1_P:_'Germany'
# 3                  D:_'Germany'_matchB1_P:_'Germany'
# 4                  D:_'Germany'_matchB1_P:_'Germany'
#
#                        area1_of_rattachment area2_of_rattachment  \
# 0                                   Germany              Missing
# 1  Old_(before_year_1993_AD)_Czech_Republic              Missing
# 2                                   Germany              Missing
# 3                                   Germany              Missing
# 4         Old_(before_year_1990_AD)_Germany              Missing
#
#                              list_wikipedia_editions un_region  \
# 0                                             dewiki    Europe
# 1  dewiki|cswiki|enwiki|eowiki|itwiki|kkwiki|rowi...    Europe
# 2                                             dewiki    Europe
# 3                                             dewiki    Europe
# 4                                             dewiki    Europe
#
#   group_wikipedia_editions      bplo1      dplo1      bpla1      dpla1  \
# 0                      grB  11.833333  12.420000  53.416668  54.381390
# 1                      grA  12.929798  14.421389  49.440605  50.087502
# 2                      grB   9.191944        NaN  48.897499        NaN
# 3                      grB  13.383333        NaN  52.516666        NaN
# 4                      grB  13.350000   8.400000  52.433300  49.016666
#
#    pantheon_1                                     level3_all_occ date_of_birth
# 0           0  D:_playwright_journalist_writer_screenwriter_P...
# 1           0  D:_writer_journalist_P:_naturalist_writer_jour...
# 2           0  D:_film_screenwriter_film_P:_regisseur_autor_f...
# 3           0                      D:_actor_P:_schauspiel_German
# 4           0      D:_judge_jurist_P:_ richter_verfassung_German

# %%
from typing import *

def insert_date_of_birth(df, wikidata_client, failed_wikicodes: List):
    failed_wikicodes = []
    date_of_birth = client.get('P569')
    count = 0
    for index, row in df.iterrows():
        count += 1
        wikidata_code = row['wikidata_code']
        data = wikidata_client.get(wikidata_code)
        if count%1000 == 0:
            print('{0} data processed...', index)
            
        try:
            birthday = data[date_of_birth]
            df.at[index, 'date_of_birth'] = birthday
        except Exception as error:
            print('Failed to get date of birth at row {0}, with wikidata code {1}: {2}'
                  .format(index, wikidata_code, error))
            failed_wikicodes.append(wikidata_code)

# %%
failed_codes = []
insert_date_of_birth(test_data, client, failed_codes)
# Out:
# {0} data processed... 0

# %%
test_data
# Out:
#   wikidata_code   birth   death  updated_death_date approx_birth approx_death  \
# 0      Q1000002  1932.0  1990.0                 NaN          NaN          NaN
# 1      Q1000005  1860.0  1927.0                 NaN          NaN          NaN
# 2      Q1000006  1971.0     NaN                 NaN          NaN          NaN
# 3      Q1000015  1983.0     NaN                 NaN          NaN          NaN
# 4      Q1000023  1912.0  1977.0                 NaN          NaN          NaN
#
#    birth_min  birth_max  death_min  death_max  gender level1_main_occ  \
# 0     1932.0     1932.0     1990.0     1990.0    Male         Culture
# 1     1860.0     1860.0     1927.0     1927.0    Male         Culture
# 2     1971.0     1971.0        NaN        NaN    Male         Culture
# 3     1983.0     1983.0        NaN        NaN    Male         Culture
# 4     1912.0     1912.0     1977.0     1977.0  Female      Leadership
#
#                           name    un_subregion  birth_estimation  \
# 0                 Claus_Hammel  Western Europe            1932.0
# 1     Karel_MatÄj_Äapek-Chod  Western Europe            1860.0
# 2            Florian_Eichinger  Western Europe            1971.0
# 3                 Florian_Jahr  Western Europe            1983.0
# 4  Wiltraut_Rupp-von_BrÃ¼nneck  Western Europe            1912.0
#
#    death_estimation            bigperiod_birth_graph_b  \
# 0         1990.0000  5.Contemporary period 1901-2020AD
# 1         1927.0000    4.Mid Modern Period 1751-1900AD
# 2         2053.8447  5.Contemporary period 1901-2020AD
# 3         2067.1899  5.Contemporary period 1901-2020AD
# 4         1977.0000  5.Contemporary period 1901-2020AD
#
#              bigperiod_death_graph_b    curid     level2_main_occ  \
# 0  5.Contemporary period 1901-2020AD  2949539        Culture-core
# 1  5.Contemporary period 1901-2020AD  4217319        Culture-core
# 2  5.Contemporary period 1901-2020AD  5050967        Culture-core
# 3  5.Contemporary period 1901-2020AD  2588583        Culture-core
# 4  5.Contemporary period 1901-2020AD   922120  Administration/Law
#
#    freq_main_occ  freq_second_occ  level2_second_occ level3_main_occ  \
# 0       0.800000         0.200000  Culture-periphery      playwright
# 1       0.538462         0.307692  Culture-periphery          writer
# 2       1.000000              NaN            Missing            film
# 3       1.000000              NaN            Missing           actor
# 4       0.833333         0.166667           Politics           judge
#
#                      bigperiod_birth                    bigperiod_death  \
# 0  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 1    4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 2  5.Contemporary period 1901-2020AD                            Missing
# 3  5.Contemporary period 1901-2020AD                            Missing
# 4  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
#
#    wiki_readers_2015_2018  non_missing_score  total_count_words_b  \
# 0                    1669                  3                 1777
# 1                   25008                  3                 6491
# 2                   27285                  3                 1573
# 3                   37331                  3                 1931
# 4                    2955                  3                 1578
#
#    number_wiki_editions  total_noccur_links_b  sum_visib_ln_5criteria  \
# 0                     1                    11               18.083672
# 1                     9                    15               23.980610
# 2                     1                    10               20.666656
# 3                     1                    10               21.185040
# 4                     1                     6               17.996210
#
#    ranking_visib_5criteria all_geography_groups string_citizenship_raw_d  \
# 0                1058542.0              Germany                'Germany'
# 1                 131428.0       Czech_Republic         'Czech_Republic'
# 2                 775768.0              Germany                'Germany'
# 3                 691735.0              Germany                'Germany'
# 4                1103282.0              Germany                'Germany'
#
#   citizenship_1_b citizenship_2_b  \
# 0         Germany             NaN
# 1  Czech_Republic             NaN
# 2         Germany             NaN
# 3         Germany             NaN
# 4         Germany             NaN
#
#                                list_areas_of_rattach  \
# 0                  D:_'Germany'_matchB1_P:_'Germany'
# 1  D:_'Czech_Republic'_mismatchB2_P:_'Czech_Repub...
# 2                  D:_'Germany'_matchB1_P:_'Germany'
# 3                  D:_'Germany'_matchB1_P:_'Germany'
# 4                  D:_'Germany'_matchB1_P:_'Germany'
#
#                        area1_of_rattachment area2_of_rattachment  \
# 0                                   Germany              Missing
# 1  Old_(before_year_1993_AD)_Czech_Republic              Missing
# 2                                   Germany              Missing
# 3                                   Germany              Missing
# 4         Old_(before_year_1990_AD)_Germany              Missing
#
#                              list_wikipedia_editions un_region  \
# 0                                             dewiki    Europe
# 1  dewiki|cswiki|enwiki|eowiki|itwiki|kkwiki|rowi...    Europe
# 2                                             dewiki    Europe
# 3                                             dewiki    Europe
# 4                                             dewiki    Europe
#
#   group_wikipedia_editions      bplo1      dplo1      bpla1      dpla1  \
# 0                      grB  11.833333  12.420000  53.416668  54.381390
# 1                      grA  12.929798  14.421389  49.440605  50.087502
# 2                      grB   9.191944        NaN  48.897499        NaN
# 3                      grB  13.383333        NaN  52.516666        NaN
# 4                      grB  13.350000   8.400000  52.433300  49.016666
#
#    pantheon_1                                     level3_all_occ date_of_birth
# 0           0  D:_playwright_journalist_writer_screenwriter_P...    1932-12-04
# 1           0  D:_writer_journalist_P:_naturalist_writer_jour...    1860-02-21
# 2           0  D:_film_screenwriter_film_P:_regisseur_autor_f...    1971-07-14
# 3           0                      D:_actor_P:_schauspiel_German    1983-06-23
# 4           0      D:_judge_jurist_P:_ richter_verfassung_German    1912-08-07

# %% [markdown]
# # Add date of birth the all data

# %% [markdown]
# Add another column to the dataframe

# %%
df["date_of_birth"] = ""

# %%
df
# Out:
#         wikidata_code   birth   death  updated_death_date approx_birth  \
# 0            Q1000002  1932.0  1990.0                 NaN          NaN
# 1            Q1000005  1860.0  1927.0                 NaN          NaN
# 2            Q1000006  1971.0     NaN                 NaN          NaN
# 3            Q1000015  1983.0     NaN                 NaN          NaN
# 4            Q1000023  1912.0  1977.0                 NaN          NaN
# ...               ...     ...     ...                 ...          ...
# 2291812       Q999994  1988.0     NaN                 NaN          NaN
# 2291813       Q999995  1987.0     NaN                 NaN        circa
# 2291814       Q999997  1984.0     NaN                 NaN          NaN
# 2291815       Q999998  1952.0     NaN                 NaN          NaN
# 2291816       Q999999  1982.0     NaN                 NaN          NaN
#
#         approx_death  birth_min  birth_max  death_min  death_max  gender  \
# 0                NaN     1932.0     1932.0     1990.0     1990.0    Male
# 1                NaN     1860.0     1860.0     1927.0     1927.0    Male
# 2                NaN     1971.0     1971.0        NaN        NaN    Male
# 3                NaN     1983.0     1983.0        NaN        NaN    Male
# 4                NaN     1912.0     1912.0     1977.0     1977.0  Female
# ...              ...        ...        ...        ...        ...     ...
# 2291812          NaN     1988.0     1988.0        NaN        NaN    Male
# 2291813          NaN     1987.0     1987.0        NaN        NaN    Male
# 2291814          NaN     1984.0     1984.0        NaN        NaN    Male
# 2291815          NaN     1952.0     1952.0        NaN        NaN    Male
# 2291816          NaN     1982.0     1982.0        NaN        NaN  Female
#
#         level1_main_occ                         name     un_subregion  \
# 0               Culture                 Claus_Hammel   Western Europe
# 1               Culture     Karel_MatÄj_Äapek-Chod   Western Europe
# 2               Culture            Florian_Eichinger   Western Europe
# 3               Culture                 Florian_Jahr   Western Europe
# 4            Leadership  Wiltraut_Rupp-von_BrÃ¼nneck   Western Europe
# ...                 ...                          ...              ...
# 2291812    Sports/Games                Mitja_MeÅ¾nar  Southern Europe
# 2291813    Sports/Games                  Martin_Cikl   Western Europe
# 2291814    Sports/Games     Vincent_Descombes_Sevoie   Western Europe
# 2291815         Culture              JosÃ©_Massaroli    South America
# 2291816    Sports/Games                Seraina_Boner   Western Europe
#
#          birth_estimation  death_estimation  \
# 0                  1932.0         1990.0000
# 1                  1860.0         1927.0000
# 2                  1971.0         2053.8447
# 3                  1983.0         2067.1899
# 4                  1912.0         1977.0000
# ...                   ...               ...
# 2291812            1988.0         2065.3259
# 2291813            1987.0         2065.1482
# 2291814            1984.0         2061.8308
# 2291815            1952.0         2032.8303
# 2291816            1982.0         2055.6638
#
#                    bigperiod_birth_graph_b            bigperiod_death_graph_b  \
# 0        5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 1          4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 2        5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 3        5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 4        5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# ...                                    ...                                ...
# 2291812  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2291813  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2291814  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2291815  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2291816  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
#
#             curid     level2_main_occ  freq_main_occ  freq_second_occ  \
# 0         2949539        Culture-core       0.800000         0.200000
# 1         4217319        Culture-core       0.538462         0.307692
# 2         5050967        Culture-core       1.000000              NaN
# 3         2588583        Culture-core       1.000000              NaN
# 4          922120  Administration/Law       0.833333         0.166667
# ...           ...                 ...            ...              ...
# 2291812  20581328        Sports/Games       0.900000              NaN
# 2291813  16791925        Sports/Games       0.923077              NaN
# 2291814  21384087        Sports/Games       0.909091              NaN
# 2291815  11512070        Culture-core       0.875000              NaN
# 2291816  41897786        Sports/Games       1.000000              NaN
#
#          level2_second_occ level3_main_occ                    bigperiod_birth  \
# 0        Culture-periphery      playwright  5.Contemporary period 1901-2020AD
# 1        Culture-periphery          writer    4.Mid Modern Period 1751-1900AD
# 2                  Missing            film  5.Contemporary period 1901-2020AD
# 3                  Missing           actor  5.Contemporary period 1901-2020AD
# 4                 Politics           judge  5.Contemporary period 1901-2020AD
# ...                    ...             ...                                ...
# 2291812            Missing             ski  5.Contemporary period 1901-2020AD
# 2291813            Missing             ski  5.Contemporary period 1901-2020AD
# 2291814            Missing             ski  5.Contemporary period 1901-2020AD
# 2291815            Missing          artist  5.Contemporary period 1901-2020AD
# 2291816            Missing           skier  5.Contemporary period 1901-2020AD
#
#                            bigperiod_death  wiki_readers_2015_2018  \
# 0        5.Contemporary period 1901-2020AD                    1669
# 1        5.Contemporary period 1901-2020AD                   25008
# 2                                  Missing                   27285
# 3                                  Missing                   37331
# 4        5.Contemporary period 1901-2020AD                    2955
# ...                                    ...                     ...
# 2291812                            Missing                    8896
# 2291813                            Missing                    8807
# 2291814                            Missing                   51786
# 2291815                            Missing                    3772
# 2291816                            Missing                   12052
#
#          non_missing_score  total_count_words_b  number_wiki_editions  \
# 0                        3                 1777                     1
# 1                        3                 6491                     9
# 2                        3                 1573                     1
# 3                        3                 1931                     1
# 4                        3                 1578                     1
# ...                    ...                  ...                   ...
# 2291812                  3                 5668                     8
# 2291813                  3                 6096                     9
# 2291814                  3                14372                     7
# 2291815                  3                 5570                     3
# 2291816                  3                 8369                     8
#
#          total_noccur_links_b  sum_visib_ln_5criteria  \
# 0                          11               18.083672
# 1                          15               23.980610
# 2                          10               20.666656
# 3                          10               21.185040
# 4                           6               17.996210
# ...                       ...                     ...
# 2291812                     4               21.543238
# 2291813                     4               21.711330
# 2291814                     6               24.453411
# 2291815                     6               20.193954
# 2291816                     3               22.013247
#
#          ranking_visib_5criteria all_geography_groups  \
# 0                      1058542.0              Germany
# 1                       131428.0       Czech_Republic
# 2                       775768.0              Germany
# 3                       691735.0              Germany
# 4                      1103282.0              Germany
# ...                          ...                  ...
# 2291812                 350041.5             Slovenia
# 2291813                 339942.5       Czech_Republic
# 2291814                 154890.0               France
# 2291815                 453953.0            Argentina
# 2291816                 344726.0          Switzerland
#
#         string_citizenship_raw_d citizenship_1_b citizenship_2_b  \
# 0                      'Germany'         Germany             NaN
# 1               'Czech_Republic'  Czech_Republic             NaN
# 2                      'Germany'         Germany             NaN
# 3                      'Germany'         Germany             NaN
# 4                      'Germany'         Germany             NaN
# ...                          ...             ...             ...
# 2291812               'Slovenia'        Slovenia             NaN
# 2291813         'Czech_Republic'  Czech_Republic             NaN
# 2291814                 'France'          France             NaN
# 2291815              'Argentina'       Argentina             NaN
# 2291816            'Switzerland'     Switzerland             NaN
#
#                                      list_areas_of_rattach  \
# 0                        D:_'Germany'_matchB1_P:_'Germany'
# 1        D:_'Czech_Republic'_mismatchB2_P:_'Czech_Repub...
# 2                        D:_'Germany'_matchB1_P:_'Germany'
# 3                        D:_'Germany'_matchB1_P:_'Germany'
# 4                        D:_'Germany'_matchB1_P:_'Germany'
# ...                                                    ...
# 2291812                D:_'Slovenia'_matchB1_P:_'Slovenia'
# 2291813    D:_'Czech_Republic'_matchB1_P:_'Czech_Republic'
# 2291814                    D:_'France'_matchB1_P:_'France'
# 2291815              D:_'Argentina'_matchB1_P:_'Argentina'
# 2291816          D:_'Switzerland'_matchB1_P:_'Switzerland'
#
#                              area1_of_rattachment area2_of_rattachment  \
# 0                                         Germany              Missing
# 1        Old_(before_year_1993_AD)_Czech_Republic              Missing
# 2                                         Germany              Missing
# 3                                         Germany              Missing
# 4               Old_(before_year_1990_AD)_Germany              Missing
# ...                                           ...                  ...
# 2291812                                  Slovenia              Missing
# 2291813                            Czech_Republic              Missing
# 2291814                                    France              Missing
# 2291815                                 Argentina              Missing
# 2291816                               Switzerland              Missing
#
#                                    list_wikipedia_editions un_region  \
# 0                                                   dewiki    Europe
# 1        dewiki|cswiki|enwiki|eowiki|itwiki|kkwiki|rowi...    Europe
# 2                                                   dewiki    Europe
# 3                                                   dewiki    Europe
# 4                                                   dewiki    Europe
# ...                                                    ...       ...
# 2291812  fiwiki|dewiki|enwiki|frwiki|nowiki|plwiki|ruwi...    Europe
# 2291813  fiwiki|dewiki|enwiki|frwiki|nowiki|plwiki|ruwi...    Europe
# 2291814   fiwiki|dewiki|enwiki|frwiki|nowiki|plwiki|ruwiki    Europe
# 2291815                               fiwiki|enwiki|eswiki   America
# 2291816  fiwiki|nowiki|plwiki|svwiki|dewiki|enwiki|ruwi...    Europe
#
#         group_wikipedia_editions      bplo1      dplo1      bpla1      dpla1  \
# 0                            grB  11.833333  12.420000  53.416668  54.381390
# 1                            grA  12.929798  14.421389  49.440605  50.087502
# 2                            grB   9.191944        NaN  48.897499        NaN
# 3                            grB  13.383333        NaN  52.516666        NaN
# 4                            grB  13.350000   8.400000  52.433300  49.016666
# ...                          ...        ...        ...        ...        ...
# 2291812                      grA  14.355610        NaN  46.238869        NaN
# 2291813                      grA  14.618354        NaN  50.911613        NaN
# 2291814                      grA   6.868889        NaN  45.922222        NaN
# 2291815                      grA -60.000000        NaN -33.483334        NaN
# 2291816                      grA   9.839833        NaN  46.809055        NaN
#
#          pantheon_1                                     level3_all_occ  \
# 0                 0  D:_playwright_journalist_writer_screenwriter_P...
# 1                 0  D:_writer_journalist_P:_naturalist_writer_jour...
# 2                 0  D:_film_screenwriter_film_P:_regisseur_autor_f...
# 3                 0                      D:_actor_P:_schauspiel_German
# 4                 0      D:_judge_jurist_P:_ richter_verfassung_German
# ...             ...                                                ...
# 2291812           0  D:_ski_P:_ ski_jumper_olympic_English_auteur_s...
# 2291813           0  D:_ski_P:_ ski_jumper_olympic_English_auteur_s...
# 2291814           0  D:_ski_skier_P:_ ski_jumper_English_auteur_ski...
# 2291815           0  D:_artist_P:_ comic_artist_comic_English_dibuj...
# 2291816           0  D:_skier_P:_cross country_skier_olympic_Englis...
#
#         date_of_birth
# 0
# 1
# 2
# 3
# 4
# ...               ...
# 2291812
# 2291813
# 2291814
# 2291815
# 2291816
#
# [2291817 rows x 50 columns]

# %%
dfs = []
row_count = df.shape[0]

# %%
row_count
chunk_count = 10
chunk_size = row_count // chunk_count

# %%
chunk_size
# Out:
# 229181

# %%
df
# Out:
#         wikidata_code   birth   death  updated_death_date approx_birth  \
# 0            Q1000002  1932.0  1990.0                 NaN          NaN
# 1            Q1000005  1860.0  1927.0                 NaN          NaN
# 2            Q1000006  1971.0     NaN                 NaN          NaN
# 3            Q1000015  1983.0     NaN                 NaN          NaN
# 4            Q1000023  1912.0  1977.0                 NaN          NaN
# ...               ...     ...     ...                 ...          ...
# 2291812       Q999994  1988.0     NaN                 NaN          NaN
# 2291813       Q999995  1987.0     NaN                 NaN        circa
# 2291814       Q999997  1984.0     NaN                 NaN          NaN
# 2291815       Q999998  1952.0     NaN                 NaN          NaN
# 2291816       Q999999  1982.0     NaN                 NaN          NaN
#
#         approx_death  birth_min  birth_max  death_min  death_max  ...  \
# 0                NaN     1932.0     1932.0     1990.0     1990.0  ...
# 1                NaN     1860.0     1860.0     1927.0     1927.0  ...
# 2                NaN     1971.0     1971.0        NaN        NaN  ...
# 3                NaN     1983.0     1983.0        NaN        NaN  ...
# 4                NaN     1912.0     1912.0     1977.0     1977.0  ...
# ...              ...        ...        ...        ...        ...  ...
# 2291812          NaN     1988.0     1988.0        NaN        NaN  ...
# 2291813          NaN     1987.0     1987.0        NaN        NaN  ...
# 2291814          NaN     1984.0     1984.0        NaN        NaN  ...
# 2291815          NaN     1952.0     1952.0        NaN        NaN  ...
# 2291816          NaN     1982.0     1982.0        NaN        NaN  ...
#
#                                    list_wikipedia_editions un_region  \
# 0                                                   dewiki    Europe
# 1        dewiki|cswiki|enwiki|eowiki|itwiki|kkwiki|rowi...    Europe
# 2                                                   dewiki    Europe
# 3                                                   dewiki    Europe
# 4                                                   dewiki    Europe
# ...                                                    ...       ...
# 2291812  fiwiki|dewiki|enwiki|frwiki|nowiki|plwiki|ruwi...    Europe
# 2291813  fiwiki|dewiki|enwiki|frwiki|nowiki|plwiki|ruwi...    Europe
# 2291814   fiwiki|dewiki|enwiki|frwiki|nowiki|plwiki|ruwiki    Europe
# 2291815                               fiwiki|enwiki|eswiki   America
# 2291816  fiwiki|nowiki|plwiki|svwiki|dewiki|enwiki|ruwi...    Europe
#
#         group_wikipedia_editions      bplo1      dplo1      bpla1      dpla1  \
# 0                            grB  11.833333  12.420000  53.416668  54.381390
# 1                            grA  12.929798  14.421389  49.440605  50.087502
# 2                            grB   9.191944        NaN  48.897499        NaN
# 3                            grB  13.383333        NaN  52.516666        NaN
# 4                            grB  13.350000   8.400000  52.433300  49.016666
# ...                          ...        ...        ...        ...        ...
# 2291812                      grA  14.355610        NaN  46.238869        NaN
# 2291813                      grA  14.618354        NaN  50.911613        NaN
# 2291814                      grA   6.868889        NaN  45.922222        NaN
# 2291815                      grA -60.000000        NaN -33.483334        NaN
# 2291816                      grA   9.839833        NaN  46.809055        NaN
#
#         pantheon_1                                     level3_all_occ  \
# 0                0  D:_playwright_journalist_writer_screenwriter_P...
# 1                0  D:_writer_journalist_P:_naturalist_writer_jour...
# 2                0  D:_film_screenwriter_film_P:_regisseur_autor_f...
# 3                0                      D:_actor_P:_schauspiel_German
# 4                0      D:_judge_jurist_P:_ richter_verfassung_German
# ...            ...                                                ...
# 2291812          0  D:_ski_P:_ ski_jumper_olympic_English_auteur_s...
# 2291813          0  D:_ski_P:_ ski_jumper_olympic_English_auteur_s...
# 2291814          0  D:_ski_skier_P:_ ski_jumper_English_auteur_ski...
# 2291815          0  D:_artist_P:_ comic_artist_comic_English_dibuj...
# 2291816          0  D:_skier_P:_cross country_skier_olympic_Englis...
#
#         date_of_birth
# 0
# 1
# 2
# 3
# 4
# ...               ...
# 2291812
# 2291813
# 2291814
# 2291815
# 2291816
#
# [2291817 rows x 50 columns]

# %%
df_rank_2000 = df[df['ranking_visib_5criteria'] <= 2000]

# %%
df_rank_2000
# Out:
#         wikidata_code   birth   death  updated_death_date approx_birth  \
# 174             Q1001  1869.0  1948.0                 NaN          NaN
# 1232          Q100937  1899.0  1987.0                 NaN          NaN
# 1257          Q100948  1907.0  1964.0                 NaN          NaN
# 1699           Q10132  1986.0     NaN                 NaN          NaN
# 1769          Q101410  1954.0     NaN                 NaN          NaN
# ...               ...     ...     ...                 ...          ...
# 2289106          Q989  1920.0  2005.0                 NaN          NaN
# 2289464          Q991  1821.0  1881.0                 NaN          NaN
# 2289600         Q9916  1890.0  1969.0                 NaN          NaN
# 2291069         Q9960  1911.0  2004.0                 NaN          NaN
# 2291242          Q997  1921.0  1989.0                 NaN          NaN
#
#         approx_death  birth_min  birth_max  death_min  death_max  gender  \
# 174              NaN     1869.0     1869.0     1948.0     1948.0    Male
# 1232             NaN     1899.0     1899.0     1987.0     1987.0    Male
# 1257             NaN     1907.0     1907.0     1964.0     1964.0  Female
# 1699             NaN     1986.0     1986.0        NaN        NaN    Male
# 1769             NaN     1954.0     1954.0        NaN        NaN    Male
# ...              ...        ...        ...        ...        ...     ...
# 2289106          NaN     1920.0     1920.0     2005.0     2005.0    Male
# 2289464          NaN     1821.0     1821.0     1881.0     1881.0    Male
# 2289600          NaN     1890.0     1890.0     1969.0     1969.0    Male
# 2291069          NaN     1911.0     1911.0     2004.0     2004.0    Male
# 2291242          NaN     1921.0     1921.0     1989.0     1989.0    Male
#
#            level1_main_occ                  name  \
# 174             Leadership        Mahatma_Gandhi
# 1232               Culture          Fred_Astaire
# 1257     Discovery/Science         Rachel_Carson
# 1699          Sports/Games          Rafael_Nadal
# 1769            Leadership      FranÃ§ois_Fillon
# ...                    ...                   ...
# 2289106         Leadership     Pope_John_Paul_II
# 2289464            Culture     Fyodor_Dostoevsky
# 2289600         Leadership  Dwight_D._Eisenhower
# 2291069            Culture         Ronald_Reagan
# 2291242  Discovery/Science       Andrei_Sakharov
#
#                               un_subregion  birth_estimation  \
# 174      South Asia incl. Indian Peninsula            1869.0
# 1232                      Northern America            1899.0
# 1257                      Northern America            1907.0
# 1699                       Southern Europe            1986.0
# 1769                        Western Europe            1954.0
# ...                                    ...               ...
# 2289106                     Eastern Europe            1920.0
# 2289464                     Eastern Europe            1821.0
# 2289600                   Northern America            1890.0
# 2291069                   Northern America            1911.0
# 2291242                     Eastern Europe            1921.0
#
#          death_estimation            bigperiod_birth_graph_b  \
# 174             1948.0000    4.Mid Modern Period 1751-1900AD
# 1232            1987.0000    4.Mid Modern Period 1751-1900AD
# 1257            1964.0000  5.Contemporary period 1901-2020AD
# 1699            2063.1160  5.Contemporary period 1901-2020AD
# 1769            2030.0797  5.Contemporary period 1901-2020AD
# ...                   ...                                ...
# 2289106         2005.0000  5.Contemporary period 1901-2020AD
# 2289464         1881.0000    4.Mid Modern Period 1751-1900AD
# 2289600         1969.0000    4.Mid Modern Period 1751-1900AD
# 2291069         2004.0000  5.Contemporary period 1901-2020AD
# 2291242         1989.0000  5.Contemporary period 1901-2020AD
#
#                    bigperiod_death_graph_b    curid level2_main_occ  \
# 174      5.Contemporary period 1901-2020AD    19379        Politics
# 1232     5.Contemporary period 1901-2020AD    64962    Culture-core
# 1257     5.Contemporary period 1901-2020AD    81274        Academia
# 1699     5.Contemporary period 1901-2020AD  1439517    Sports/Games
# 1769     5.Contemporary period 1901-2020AD  6111238        Politics
# ...                                    ...      ...             ...
# 2289106  5.Contemporary period 1901-2020AD    23805       Religious
# 2289464    4.Mid Modern Period 1751-1900AD    11625    Culture-core
# 2289600  5.Contemporary period 1901-2020AD     8182        Military
# 2291069  5.Contemporary period 1901-2020AD    25433    Culture-core
# 2291242  5.Contemporary period 1901-2020AD     2786        Academia
#
#          freq_main_occ  freq_second_occ   level2_second_occ level3_main_occ  \
# 174           0.409091         0.181818        Culture-core      politician
# 1232          0.953488              NaN             Missing           actor
# 1257          0.441176         0.323529        Culture-core       biologist
# 1699          0.857143              NaN             Missing          player
# 1769          0.807692         0.153846  Administration/Law      politician
# ...                ...              ...                 ...             ...
# 2289106       0.470588         0.176471        Culture-core          priest
# 2289464       0.578947         0.184211            Academia        novelist
# 2289600       0.464286         0.392857            Politics            army
# 2291069       0.487805         0.414634            Politics           actor
# 2291242       0.500000         0.444444            Politics       physicist
#
#                            bigperiod_birth                    bigperiod_death  \
# 174        4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 1232       4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 1257     5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 1699     5.Contemporary period 1901-2020AD                            Missing
# 1769     5.Contemporary period 1901-2020AD                            Missing
# ...                                    ...                                ...
# 2289106  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2289464    4.Mid Modern Period 1751-1900AD    4.Mid Modern Period 1751-1900AD
# 2289600    4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 2291069  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2291242  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
#
#          wiki_readers_2015_2018  non_missing_score  total_count_words_b  \
# 174                    54379472                  3               191606
# 1232                    6224676                  3                63143
# 1257                    1821105                  3                70880
# 1699                   32249952                  3               347862
# 1769                    5424258                  3               106332
# ...                         ...                ...                  ...
# 2289106                19123836                  3               233416
# 2289464                12878684                  3               127400
# 2289600                 6613569                  3               150067
# 2291069                37631824                  3               227295
# 2291242                 2692700                  3                60534
#
#          number_wiki_editions  total_noccur_links_b  sum_visib_ln_5criteria  \
# 174                       172                    90               39.638851
# 1232                       78                    67               35.286160
# 1257                       74                    44               33.707863
# 1699                      103                    37               38.330566
# 1769                       73                    35               34.968307
# ...                       ...                   ...                     ...
# 2289106                   135                    64               38.214069
# 2289464                   154                    95               37.733952
# 2289600                   124                    79               36.833820
# 2291069                   249                    81               39.705551
# 2291242                    83                    42               34.009048
#
#          ranking_visib_5criteria                         all_geography_groups  \
# 174                         11.0  Old_regimes_in_/_of_India,Dominion_of_India
# 1232                       626.5                                           US
# 1257                      1808.0                                           US
# 1699                       681.0                                        Spain
# 1769                      1273.0                                       France
# ...                          ...                                          ...
# 2289106                     91.0                   Poland,Vatican_City,Poland
# 2289464                     85.0                   Old_regimes_in_/_of_Russia
# 2289600                    231.0                                           US
# 2291069                     20.0                                           US
# 2291242                   1493.0      Former_Soviet_Union,Former_Soviet_Union
#
#                                   string_citizenship_raw_d citizenship_1_b  \
# 174                      'British_Raj'_'Dominion_of_India'           India
# 1232                                                  'US'              US
# 1257                                                  'US'              US
# 1699                                               'Spain'           Spain
# 1769                                              'France'          France
# ...                                                    ...             ...
# 2289106   'Poland'_'Vatican_City'_'Second_Polish_Republic'          Poland
# 2289464                                   'Russian_Empire'          Russia
# 2289600                                               'US'              US
# 2291069                                               'US'              US
# 2291242  'Russian_Soviet_Federative_Socialist_Republic'...          Russia
#
#         citizenship_2_b                              list_areas_of_rattach  \
# 174                 NaN  D:_'British_Raj'_'Dominion_of_India'_matchB1_P...
# 1232                NaN                            D:_'US'_matchB1_P:_'US'
# 1257                NaN                            D:_'US'_matchB1_P:_'US'
# 1699                NaN                      D:_'Spain'_matchB1_P:_'Spain'
# 1769                NaN                    D:_'France'_matchB1_P:_'France'
# ...                 ...                                                ...
# 2289106    Vatican_City  D:_'Poland'_'Vatican_City'_'Second_Polish_Repu...
# 2289464             NaN            D:_'Russian_Empire'_matchB1_P:_'Russia'
# 2289600             NaN                 D:_'US'_mismatchB2_P:_'US'_'Italy'
# 2291069             NaN                            D:_'US'_matchB1_P:_'US'
# 2291242             NaN  D:_'Russian_Soviet_Federative_Socialist_Republ...
#
#                      area1_of_rattachment area2_of_rattachment  \
# 174       Old_(before_year_1947_AD)_India              Missing
# 1232                                   US              Missing
# 1257                                   US              Missing
# 1699                                Spain              Missing
# 1769                               France              Missing
# ...                                   ...                  ...
# 2289106                            Poland         Vatican_City
# 2289464  Old_(before_year_1990_AD)_Russia              Missing
# 2289600                                US              Missing
# 2291069                                US              Missing
# 2291242                      Soviet_Union              Missing
#
#                                    list_wikipedia_editions un_region  \
# 174      guwiki|itwiki|alswiki|amwiki|anwiki|arwiki|arz...      Asia
# 1232     enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...   America
# 1257     enwiki|dewiki|frwiki|eswiki|itwiki|jawiki|nlwi...   America
# 1699     enwiki|afwiki|anwiki|astwiki|azwiki|bswiki|brw...    Europe
# 1769     zhwiki|plwiki|euwiki|eswiki|afwiki|ocwiki|huwi...    Europe
# ...                                                    ...       ...
# 2289106  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...    Europe
# 2289464  afwiki|alswiki|amwiki|arwiki|arzwiki|astwiki|a...    Europe
# 2289600  enwiki|dewiki|frwiki|eswiki|ruwiki|jawiki|nlwi...   America
# 2291069  afwiki|anwiki|frpwiki|bclwiki|bswiki|brwiki|ca...   America
# 2291242  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...    Europe
#
#         group_wikipedia_editions      bplo1       dplo1      bpla1      dpla1  \
# 174                          grA  69.604721   77.214333  21.642500  28.601860
# 1232                         grA -95.937500 -118.243683  41.258610  34.052231
# 1257                         grA -79.783356  -77.020790  40.546432  39.002441
# 1699                         grA   3.208889         NaN  39.570000        NaN
# 1769                         grA   0.196944         NaN  48.004166        NaN
# ...                          ...        ...         ...        ...        ...
# 2289106                      grA  19.500000   12.456388  49.883335  41.903610
# 2289464                      grA  37.611946   30.316668  55.783611  59.950001
# 2289600                      grA -96.557503  -77.029999  33.749699  38.974998
# 2291069                      grA -89.785301 -118.447777  41.630600  34.083328
# 2291242                      grA  37.617779   37.617779  55.755833  55.755833
#
#          pantheon_1                                     level3_all_occ  \
# 174               1  D:_politician_barrister_writer_journalist_phil...
# 1232              1  D:_actor_actor_choreographer_singer_dancer_fil...
# 1257              1  D:_biologist_environmentalist_zoologist_essayi...
# 1699              1  D:_player_model_P:_tennis_player_tennis_Englis...
# 1769              1  D:_politician_lawyer_legislative_P:_politician...
# ...             ...                                                ...
# 2289106           1  D:_priest_poet_politician_esperantist_writer_a...
# 2289464           1  D:_translator_poet_novelist_essayist_writer_jo...
# 2289600           1  D:_politician_writer_officer_statesperson_P:_ ...
# 2291069           1  D:_actor_actor_politician_biographer_actor_scr...
# 2291242           1  D:_physicist_activist_P:_physicist_dissident_a...
#
#         date_of_birth
# 174
# 1232
# 1257
# 1699
# 1769
# ...               ...
# 2289106
# 2289464
# 2289600
# 2291069
# 2291242
#
# [2000 rows x 50 columns]

# %%
failed_codes = []
insert_date_of_birth(df_rank_2000, client, failed_codes)
# Out:
# Failed to get date of birth at row 2784, with wikidata code Q102140
# Failed to get date of birth at row 3011, with wikidata code Q102272
# Failed to get date of birth at row 30172, with wikidata code Q1048
# Failed to get date of birth at row 37921, with wikidata code Q1067
# Failed to get date of birth at row 43485, with wikidata code Q108316
# Failed to get date of birth at row 53514, with wikidata code Q11104
# Failed to get date of birth at row 76267, with wikidata code Q117253
# Failed to get date of birth at row 81120, with wikidata code Q11806
# Failed to get date of birth at row 81266, with wikidata code Q11812
# Failed to get date of birth at row 89696, with wikidata code Q119702
# Failed to get date of birth at row 92347, with wikidata code Q120180
# Failed to get date of birth at row 100096, with wikidata code Q122553
# Failed to get date of birth at row 102907, with wikidata code Q123034
# Failed to get date of birth at row 110907, with wikidata code Q124617
# Failed to get date of birth at row 116382, with wikidata code Q126188
# Failed to get date of birth at row 117495, with wikidata code Q126462
# Failed to get date of birth at row 119438, with wikidata code Q12706
# Failed to get date of birth at row 120472, with wikidata code Q127318
# Failed to get date of birth at row 120869, with wikidata code Q127398
# Failed to get date of birth at row 123796, with wikidata code Q128076
# Failed to get date of birth at row 126425, with wikidata code Q12860
# Failed to get date of birth at row 129705, with wikidata code Q129247
# Failed to get date of birth at row 129922, with wikidata code Q129308
# Failed to get date of birth at row 131610, with wikidata code Q129772
# Failed to get date of birth at row 131966, with wikidata code Q129857
# Failed to get date of birth at row 132436, with wikidata code Q129987
# Failed to get date of birth at row 132990, with wikidata code Q130221
# Failed to get date of birth at row 134020, with wikidata code Q130531
# Failed to get date of birth at row 134601, with wikidata code Q130734
# Failed to get date of birth at row 134709, with wikidata code Q130777
# Failed to get date of birth at row 134773, with wikidata code Q130805
# Failed to get date of birth at row 134865, with wikidata code Q130812
# Failed to get date of birth at row 135453, with wikidata code Q131018
# Failed to get date of birth at row 136930, with wikidata code Q131412
# Failed to get date of birth at row 137166, with wikidata code Q131552
# Failed to get date of birth at row 138179, with wikidata code Q131981
# Failed to get date of birth at row 140453, with wikidata code Q132899
# Failed to get date of birth at row 140700, with wikidata code Q132964
# Failed to get date of birth at row 145017, with wikidata code Q1339
# Failed to get date of birth at row 147309, with wikidata code Q134309
# Failed to get date of birth at row 147998, with wikidata code Q134461
# Failed to get date of birth at row 150086, with wikidata code Q134958
# Failed to get date of birth at row 169862, with wikidata code Q13898
# Failed to get date of birth at row 171403, with wikidata code Q1394
# Failed to get date of birth at row 172897, with wikidata code Q1398
# Failed to get date of birth at row 173267, with wikidata code Q1399
# Failed to get date of birth at row 173863, with wikidata code Q1401
# Failed to get date of birth at row 174036, with wikidata code Q1402
# Failed to get date of birth at row 175011, with wikidata code Q1405
# Failed to get date of birth at row 176027, with wikidata code Q1407
# Failed to get date of birth at row 177042, with wikidata code Q1411
# Failed to get date of birth at row 177495, with wikidata code Q1413
# Failed to get date of birth at row 178576, with wikidata code Q141829
# Failed to get date of birth at row 180103, with wikidata code Q1425
# Failed to get date of birth at row 180511, with wikidata code Q1427
# Failed to get date of birth at row 180856, with wikidata code Q1429
# Failed to get date of birth at row 181281, with wikidata code Q1430
# Failed to get date of birth at row 182145, with wikidata code Q1434
# Failed to get date of birth at row 184183, with wikidata code Q1442
# Failed to get date of birth at row 207359, with wikidata code Q1496
# Failed to get date of birth at row 213292, with wikidata code Q150726
# Failed to get date of birth at row 220352, with wikidata code Q15189
# Failed to get date of birth at row 220431, with wikidata code Q15193
# Failed to get date of birth at row 221890, with wikidata code Q152306
# Failed to get date of birth at row 229578, with wikidata code Q1541
# Failed to get date of birth at row 282560, with wikidata code Q159636
# Failed to get date of birth at row 313377, with wikidata code Q160337
# Failed to get date of birth at row 313420, with wikidata code Q160341
# Failed to get date of birth at row 367798, with wikidata code Q162356
# Failed to get date of birth at row 382047, with wikidata code Q163900
# Failed to get date of birth at row 385057, with wikidata code Q164823
# Failed to get date of birth at row 389100, with wikidata code Q165257
# Failed to get date of birth at row 418919, with wikidata code Q167477
# Failed to get date of birth at row 453477, with wikidata code Q170472
# Failed to get date of birth at row 458589, with wikidata code Q171136
# Failed to get date of birth at row 470105, with wikidata code Q172911
# Failed to get date of birth at row 491433, with wikidata code Q174880
# Failed to get date of birth at row 504557, with wikidata code Q177854
# Failed to get date of birth at row 506550, with wikidata code Q17892
# Failed to get date of birth at row 514721, with wikidata code Q180727
# {0} data processed... 515000
# Failed to get date of birth at row 518749, with wikidata code Q181568
# Failed to get date of birth at row 566008, with wikidata code Q188411
# Failed to get date of birth at row 570517, with wikidata code Q189454
# Failed to get date of birth at row 576822, with wikidata code Q191103
# Failed to get date of birth at row 579172, with wikidata code Q192062
# Failed to get date of birth at row 613526, with wikidata code Q19810
# Failed to get date of birth at row 654536, with wikidata code Q2054
# Failed to get date of birth at row 671740, with wikidata code Q207416
# Failed to get date of birth at row 720669, with wikidata code Q215562
# Failed to get date of birth at row 724934, with wikidata code Q2161
# Failed to get date of birth at row 744588, with wikidata code Q220845
# Failed to get date of birth at row 764460, with wikidata code Q229190
# Failed to get date of birth at row 768335, with wikidata code Q23
# Failed to get date of birth at row 851778, with wikidata code Q25144
# Failed to get date of birth at row 902391, with wikidata code Q26825
# Failed to get date of birth at row 1002915, with wikidata code Q28975
# Failed to get date of birth at row 1042469, with wikidata code Q301
# Failed to get date of birth at row 1048985, with wikidata code Q302
# Failed to get date of birth at row 1056790, with wikidata code Q3044
# Failed to get date of birth at row 1066060, with wikidata code Q307
# Failed to get date of birth at row 1126687, with wikidata code Q32500
# Failed to get date of birth at row 1157030, with wikidata code Q33391
# Failed to get date of birth at row 1176072, with wikidata code Q33941
# Failed to get date of birth at row 1187389, with wikidata code Q34417
# Failed to get date of birth at row 1188610, with wikidata code Q345
# Failed to get date of birth at row 1189579, with wikidata code Q346
# Failed to get date of birth at row 1195774, with wikidata code Q34943
# Failed to get date of birth at row 1205449, with wikidata code Q35314
# Failed to get date of birth at row 1217221, with wikidata code Q35811
# Failed to get date of birth at row 1218635, with wikidata code Q35900
# Failed to get date of birth at row 1231006, with wikidata code Q36330
# Failed to get date of birth at row 1233656, with wikidata code Q36450
# Failed to get date of birth at row 1233774, with wikidata code Q36456
# Failed to get date of birth at row 1235073, with wikidata code Q36517
# Failed to get date of birth at row 1236220, with wikidata code Q36591
# Failed to get date of birth at row 1237518, with wikidata code Q36620
# Failed to get date of birth at row 1246488, with wikidata code Q37151
# Failed to get date of birth at row 1246558, with wikidata code Q37160
# Failed to get date of birth at row 1252107, with wikidata code Q37388
# Failed to get date of birth at row 1257504, with wikidata code Q37562
# Failed to get date of birth at row 1258093, with wikidata code Q37577
# Failed to get date of birth at row 1258491, with wikidata code Q37594
# Failed to get date of birth at row 1280946, with wikidata code Q38370
# Failed to get date of birth at row 1309152, with wikidata code Q39619
# Failed to get date of birth at row 1310988, with wikidata code Q39837
# Failed to get date of birth at row 1312589, with wikidata code Q39978
# Failed to get date of birth at row 1320811, with wikidata code Q40787
# Failed to get date of birth at row 1322017, with wikidata code Q40939
# Failed to get date of birth at row 1324045, with wikidata code Q41155
# Failed to get date of birth at row 1325411, with wikidata code Q41223
# Failed to get date of birth at row 1325821, with wikidata code Q41264
# Failed to get date of birth at row 1328092, with wikidata code Q41523
# Failed to get date of birth at row 1328769, with wikidata code Q41568
# Failed to get date of birth at row 1330671, with wikidata code Q41683
# Failed to get date of birth at row 1333633, with wikidata code Q41866
# Failed to get date of birth at row 1334440, with wikidata code Q41980
# Failed to get date of birth at row 1338625, with wikidata code Q42305
# Failed to get date of birth at row 1342795, with wikidata code Q42544
# Failed to get date of birth at row 1346892, with wikidata code Q42827
# Failed to get date of birth at row 1346925, with wikidata code Q42831
# Failed to get date of birth at row 1349670, with wikidata code Q42985
# Failed to get date of birth at row 1349726, with wikidata code Q42992
# Failed to get date of birth at row 1351122, with wikidata code Q43107
# Failed to get date of birth at row 1352608, with wikidata code Q43216
# Failed to get date of birth at row 1353398, with wikidata code Q43270
# Failed to get date of birth at row 1354807, with wikidata code Q43353
# Failed to get date of birth at row 1356949, with wikidata code Q43423
# Failed to get date of birth at row 1358314, with wikidata code Q43499
# Failed to get date of birth at row 1361587, with wikidata code Q43689
# Failed to get date of birth at row 1361854, with wikidata code Q43718
# Failed to get date of birth at row 1364593, with wikidata code Q43936
# Failed to get date of birth at row 1364621, with wikidata code Q43939
# Failed to get date of birth at row 1365226, with wikidata code Q43977
# Failed to get date of birth at row 1368801, with wikidata code Q44233
# Failed to get date of birth at row 1368943, with wikidata code Q44248
# Failed to get date of birth at row 1369124, with wikidata code Q44265
# Failed to get date of birth at row 1369170, with wikidata code Q44269
# Failed to get date of birth at row 1369284, with wikidata code Q44279
# Failed to get date of birth at row 1369317, with wikidata code Q44281
# Failed to get date of birth at row 1372902, with wikidata code Q44593
# Failed to get date of birth at row 1375632, with wikidata code Q448
# Failed to get date of birth at row 1388696, with wikidata code Q45859
# Failed to get date of birth at row 1390405, with wikidata code Q4604
# Failed to get date of birth at row 1395441, with wikidata code Q46599
# Failed to get date of birth at row 1401995, with wikidata code Q46830
# Failed to get date of birth at row 1439263, with wikidata code Q47551
# Failed to get date of birth at row 1446571, with wikidata code Q47674
# {0} data processed... 1463000
# Failed to get date of birth at row 1463000, with wikidata code Q48305
# Failed to get date of birth at row 1465912, with wikidata code Q485298
# Failed to get date of birth at row 1486172, with wikidata code Q49237
# Failed to get date of birth at row 1494108, with wikidata code Q49481
# Failed to get date of birth at row 1494181, with wikidata code Q49484
# Failed to get date of birth at row 1596450, with wikidata code Q5264
# Failed to get date of birth at row 1604789, with wikidata code Q52938
# Failed to get date of birth at row 1621044, with wikidata code Q53448
# Failed to get date of birth at row 1705782, with wikidata code Q5580
# Failed to get date of birth at row 1710447, with wikidata code Q5592
# Failed to get date of birth at row 1712482, with wikidata code Q5597
# Failed to get date of birth at row 1713152, with wikidata code Q5599
# Failed to get date of birth at row 1713381, with wikidata code Q56005
# Failed to get date of birth at row 1741960, with wikidata code Q5669
# Failed to get date of birth at row 1746645, with wikidata code Q5682
# Failed to get date of birth at row 1746875, with wikidata code Q5683
# Failed to get date of birth at row 1747174, with wikidata code Q5685
# Failed to get date of birth at row 1765656, with wikidata code Q5752
# Failed to get date of birth at row 1787951, with wikidata code Q58720
# Failed to get date of birth at row 1793048, with wikidata code Q590
# Failed to get date of birth at row 1838464, with wikidata code Q6101
# Failed to get date of birth at row 1839746, with wikidata code Q61064
# Failed to get date of birth at row 1872397, with wikidata code Q619
# Failed to get date of birth at row 1874929, with wikidata code Q6197
# Failed to get date of birth at row 1893195, with wikidata code Q6240
# Failed to get date of birth at row 1920852, with wikidata code Q635
# Failed to get date of birth at row 1964159, with wikidata code Q6691
# Failed to get date of birth at row 1973708, with wikidata code Q675493
# Failed to get date of birth at row 1978616, with wikidata code Q676555
# Failed to get date of birth at row 2006481, with wikidata code Q687
# Failed to get date of birth at row 2012045, with wikidata code Q692
# Failed to get date of birth at row 2030473, with wikidata code Q7071
# Failed to get date of birth at row 2034939, with wikidata code Q70991
# Failed to get date of birth at row 2062776, with wikidata code Q7198
# Failed to get date of birth at row 2062956, with wikidata code Q720
# Failed to get date of birth at row 2062957, with wikidata code Q7200
# Failed to get date of birth at row 2063392, with wikidata code Q7207
# Failed to get date of birth at row 2064669, with wikidata code Q7226
# Failed to get date of birth at row 2065380, with wikidata code Q7235
# Failed to get date of birth at row 2066475, with wikidata code Q7243
# Failed to get date of birth at row 2078347, with wikidata code Q7302
# Failed to get date of birth at row 2080716, with wikidata code Q7315
# Failed to get date of birth at row 2081696, with wikidata code Q7322
# Failed to get date of birth at row 2084358, with wikidata code Q7326
# Failed to get date of birth at row 2085861, with wikidata code Q7328
# Failed to get date of birth at row 2087829, with wikidata code Q7331
# Failed to get date of birth at row 2118132, with wikidata code Q742
# Failed to get date of birth at row 2146831, with wikidata code Q762
# Failed to get date of birth at row 2151298, with wikidata code Q765165
# Failed to get date of birth at row 2173438, with wikidata code Q7814
# Failed to get date of birth at row 2181277, with wikidata code Q78454
# Failed to get date of birth at row 2198186, with wikidata code Q797848
# Failed to get date of birth at row 2198201, with wikidata code Q79789
# Failed to get date of birth at row 2199220, with wikidata code Q7996
# Failed to get date of birth at row 2199300, with wikidata code Q79972
# Failed to get date of birth at row 2200279, with wikidata code Q8003
# Failed to get date of birth at row 2205135, with wikidata code Q8011
# Failed to get date of birth at row 2206236, with wikidata code Q80135
# Failed to get date of birth at row 2209399, with wikidata code Q8018
# Failed to get date of birth at row 2213369, with wikidata code Q80398
# Failed to get date of birth at row 2213728, with wikidata code Q80440
# Failed to get date of birth at row 2215104, with wikidata code Q80516
# Failed to get date of birth at row 2221243, with wikidata code Q80823
# Failed to get date of birth at row 2221895, with wikidata code Q81000
# Failed to get date of birth at row 2222515, with wikidata code Q81506
# Failed to get date of birth at row 2227676, with wikidata code Q82674
# Failed to get date of birth at row 2228176, with wikidata code Q82778
# Failed to get date of birth at row 2229644, with wikidata code Q83159
# Failed to get date of birth at row 2229694, with wikidata code Q83171
# Failed to get date of birth at row 2229918, with wikidata code Q83229
# Failed to get date of birth at row 2230372, with wikidata code Q83375
# Failed to get date of birth at row 2230593, with wikidata code Q83428
# Failed to get date of birth at row 2230807, with wikidata code Q83476
# Failed to get date of birth at row 2230915, with wikidata code Q835
# Failed to get date of birth at row 2231743, with wikidata code Q8409
# Failed to get date of birth at row 2231776, with wikidata code Q8413
# Failed to get date of birth at row 2232444, with wikidata code Q8462
# Failed to get date of birth at row 2232779, with wikidata code Q8479
# Failed to get date of birth at row 2233842, with wikidata code Q855
# Failed to get date of birth at row 2234379, with wikidata code Q8581
# Failed to get date of birth at row 2234500, with wikidata code Q859
# Failed to get date of birth at row 2236584, with wikidata code Q868
# Failed to get date of birth at row 2238002, with wikidata code Q8739
# Failed to get date of birth at row 2238198, with wikidata code Q8747
# Failed to get date of birth at row 2239271, with wikidata code Q8778
# Failed to get date of birth at row 2245564, with wikidata code Q8958
# Failed to get date of birth at row 2246105, with wikidata code Q8963
# Failed to get date of birth at row 2254577, with wikidata code Q9106
# Failed to get date of birth at row 2255301, with wikidata code Q913
# Failed to get date of birth at row 2258450, with wikidata code Q9200
# Failed to get date of birth at row 2262924, with wikidata code Q9294
# Failed to get date of birth at row 2264369, with wikidata code Q93227
# Failed to get date of birth at row 2265833, with wikidata code Q935
# Failed to get date of birth at row 2266958, with wikidata code Q936976
# Failed to get date of birth at row 2267643, with wikidata code Q9381
# Failed to get date of birth at row 2269771, with wikidata code Q9438
# Failed to get date of birth at row 2269864, with wikidata code Q9441
# Failed to get date of birth at row 2270410, with wikidata code Q9458
# Failed to get date of birth at row 2273161, with wikidata code Q9546
# Failed to get date of birth at row 2273447, with wikidata code Q9554
# Failed to get date of birth at row 2289464, with wikidata code Q991

# %%
df_rank_2000
# Out:
#         wikidata_code   birth   death  updated_death_date approx_birth  \
# 174             Q1001  1869.0  1948.0                 NaN          NaN
# 1232          Q100937  1899.0  1987.0                 NaN          NaN
# 1257          Q100948  1907.0  1964.0                 NaN          NaN
# 1699           Q10132  1986.0     NaN                 NaN          NaN
# 1769          Q101410  1954.0     NaN                 NaN          NaN
# ...               ...     ...     ...                 ...          ...
# 2289106          Q989  1920.0  2005.0                 NaN          NaN
# 2289464          Q991  1821.0  1881.0                 NaN          NaN
# 2289600         Q9916  1890.0  1969.0                 NaN          NaN
# 2291069         Q9960  1911.0  2004.0                 NaN          NaN
# 2291242          Q997  1921.0  1989.0                 NaN          NaN
#
#         approx_death  birth_min  birth_max  death_min  death_max  gender  \
# 174              NaN     1869.0     1869.0     1948.0     1948.0    Male
# 1232             NaN     1899.0     1899.0     1987.0     1987.0    Male
# 1257             NaN     1907.0     1907.0     1964.0     1964.0  Female
# 1699             NaN     1986.0     1986.0        NaN        NaN    Male
# 1769             NaN     1954.0     1954.0        NaN        NaN    Male
# ...              ...        ...        ...        ...        ...     ...
# 2289106          NaN     1920.0     1920.0     2005.0     2005.0    Male
# 2289464          NaN     1821.0     1821.0     1881.0     1881.0    Male
# 2289600          NaN     1890.0     1890.0     1969.0     1969.0    Male
# 2291069          NaN     1911.0     1911.0     2004.0     2004.0    Male
# 2291242          NaN     1921.0     1921.0     1989.0     1989.0    Male
#
#            level1_main_occ                  name  \
# 174             Leadership        Mahatma_Gandhi
# 1232               Culture          Fred_Astaire
# 1257     Discovery/Science         Rachel_Carson
# 1699          Sports/Games          Rafael_Nadal
# 1769            Leadership      FranÃ§ois_Fillon
# ...                    ...                   ...
# 2289106         Leadership     Pope_John_Paul_II
# 2289464            Culture     Fyodor_Dostoevsky
# 2289600         Leadership  Dwight_D._Eisenhower
# 2291069            Culture         Ronald_Reagan
# 2291242  Discovery/Science       Andrei_Sakharov
#
#                               un_subregion  birth_estimation  \
# 174      South Asia incl. Indian Peninsula            1869.0
# 1232                      Northern America            1899.0
# 1257                      Northern America            1907.0
# 1699                       Southern Europe            1986.0
# 1769                        Western Europe            1954.0
# ...                                    ...               ...
# 2289106                     Eastern Europe            1920.0
# 2289464                     Eastern Europe            1821.0
# 2289600                   Northern America            1890.0
# 2291069                   Northern America            1911.0
# 2291242                     Eastern Europe            1921.0
#
#          death_estimation            bigperiod_birth_graph_b  \
# 174             1948.0000    4.Mid Modern Period 1751-1900AD
# 1232            1987.0000    4.Mid Modern Period 1751-1900AD
# 1257            1964.0000  5.Contemporary period 1901-2020AD
# 1699            2063.1160  5.Contemporary period 1901-2020AD
# 1769            2030.0797  5.Contemporary period 1901-2020AD
# ...                   ...                                ...
# 2289106         2005.0000  5.Contemporary period 1901-2020AD
# 2289464         1881.0000    4.Mid Modern Period 1751-1900AD
# 2289600         1969.0000    4.Mid Modern Period 1751-1900AD
# 2291069         2004.0000  5.Contemporary period 1901-2020AD
# 2291242         1989.0000  5.Contemporary period 1901-2020AD
#
#                    bigperiod_death_graph_b    curid level2_main_occ  \
# 174      5.Contemporary period 1901-2020AD    19379        Politics
# 1232     5.Contemporary period 1901-2020AD    64962    Culture-core
# 1257     5.Contemporary period 1901-2020AD    81274        Academia
# 1699     5.Contemporary period 1901-2020AD  1439517    Sports/Games
# 1769     5.Contemporary period 1901-2020AD  6111238        Politics
# ...                                    ...      ...             ...
# 2289106  5.Contemporary period 1901-2020AD    23805       Religious
# 2289464    4.Mid Modern Period 1751-1900AD    11625    Culture-core
# 2289600  5.Contemporary period 1901-2020AD     8182        Military
# 2291069  5.Contemporary period 1901-2020AD    25433    Culture-core
# 2291242  5.Contemporary period 1901-2020AD     2786        Academia
#
#          freq_main_occ  freq_second_occ   level2_second_occ level3_main_occ  \
# 174           0.409091         0.181818        Culture-core      politician
# 1232          0.953488              NaN             Missing           actor
# 1257          0.441176         0.323529        Culture-core       biologist
# 1699          0.857143              NaN             Missing          player
# 1769          0.807692         0.153846  Administration/Law      politician
# ...                ...              ...                 ...             ...
# 2289106       0.470588         0.176471        Culture-core          priest
# 2289464       0.578947         0.184211            Academia        novelist
# 2289600       0.464286         0.392857            Politics            army
# 2291069       0.487805         0.414634            Politics           actor
# 2291242       0.500000         0.444444            Politics       physicist
#
#                            bigperiod_birth                    bigperiod_death  \
# 174        4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 1232       4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 1257     5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 1699     5.Contemporary period 1901-2020AD                            Missing
# 1769     5.Contemporary period 1901-2020AD                            Missing
# ...                                    ...                                ...
# 2289106  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2289464    4.Mid Modern Period 1751-1900AD    4.Mid Modern Period 1751-1900AD
# 2289600    4.Mid Modern Period 1751-1900AD  5.Contemporary period 1901-2020AD
# 2291069  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
# 2291242  5.Contemporary period 1901-2020AD  5.Contemporary period 1901-2020AD
#
#          wiki_readers_2015_2018  non_missing_score  total_count_words_b  \
# 174                    54379472                  3               191606
# 1232                    6224676                  3                63143
# 1257                    1821105                  3                70880
# 1699                   32249952                  3               347862
# 1769                    5424258                  3               106332
# ...                         ...                ...                  ...
# 2289106                19123836                  3               233416
# 2289464                12878684                  3               127400
# 2289600                 6613569                  3               150067
# 2291069                37631824                  3               227295
# 2291242                 2692700                  3                60534
#
#          number_wiki_editions  total_noccur_links_b  sum_visib_ln_5criteria  \
# 174                       172                    90               39.638851
# 1232                       78                    67               35.286160
# 1257                       74                    44               33.707863
# 1699                      103                    37               38.330566
# 1769                       73                    35               34.968307
# ...                       ...                   ...                     ...
# 2289106                   135                    64               38.214069
# 2289464                   154                    95               37.733952
# 2289600                   124                    79               36.833820
# 2291069                   249                    81               39.705551
# 2291242                    83                    42               34.009048
#
#          ranking_visib_5criteria                         all_geography_groups  \
# 174                         11.0  Old_regimes_in_/_of_India,Dominion_of_India
# 1232                       626.5                                           US
# 1257                      1808.0                                           US
# 1699                       681.0                                        Spain
# 1769                      1273.0                                       France
# ...                          ...                                          ...
# 2289106                     91.0                   Poland,Vatican_City,Poland
# 2289464                     85.0                   Old_regimes_in_/_of_Russia
# 2289600                    231.0                                           US
# 2291069                     20.0                                           US
# 2291242                   1493.0      Former_Soviet_Union,Former_Soviet_Union
#
#                                   string_citizenship_raw_d citizenship_1_b  \
# 174                      'British_Raj'_'Dominion_of_India'           India
# 1232                                                  'US'              US
# 1257                                                  'US'              US
# 1699                                               'Spain'           Spain
# 1769                                              'France'          France
# ...                                                    ...             ...
# 2289106   'Poland'_'Vatican_City'_'Second_Polish_Republic'          Poland
# 2289464                                   'Russian_Empire'          Russia
# 2289600                                               'US'              US
# 2291069                                               'US'              US
# 2291242  'Russian_Soviet_Federative_Socialist_Republic'...          Russia
#
#         citizenship_2_b                              list_areas_of_rattach  \
# 174                 NaN  D:_'British_Raj'_'Dominion_of_India'_matchB1_P...
# 1232                NaN                            D:_'US'_matchB1_P:_'US'
# 1257                NaN                            D:_'US'_matchB1_P:_'US'
# 1699                NaN                      D:_'Spain'_matchB1_P:_'Spain'
# 1769                NaN                    D:_'France'_matchB1_P:_'France'
# ...                 ...                                                ...
# 2289106    Vatican_City  D:_'Poland'_'Vatican_City'_'Second_Polish_Repu...
# 2289464             NaN            D:_'Russian_Empire'_matchB1_P:_'Russia'
# 2289600             NaN                 D:_'US'_mismatchB2_P:_'US'_'Italy'
# 2291069             NaN                            D:_'US'_matchB1_P:_'US'
# 2291242             NaN  D:_'Russian_Soviet_Federative_Socialist_Republ...
#
#                      area1_of_rattachment area2_of_rattachment  \
# 174       Old_(before_year_1947_AD)_India              Missing
# 1232                                   US              Missing
# 1257                                   US              Missing
# 1699                                Spain              Missing
# 1769                               France              Missing
# ...                                   ...                  ...
# 2289106                            Poland         Vatican_City
# 2289464  Old_(before_year_1990_AD)_Russia              Missing
# 2289600                                US              Missing
# 2291069                                US              Missing
# 2291242                      Soviet_Union              Missing
#
#                                    list_wikipedia_editions un_region  \
# 174      guwiki|itwiki|alswiki|amwiki|anwiki|arwiki|arz...      Asia
# 1232     enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...   America
# 1257     enwiki|dewiki|frwiki|eswiki|itwiki|jawiki|nlwi...   America
# 1699     enwiki|afwiki|anwiki|astwiki|azwiki|bswiki|brw...    Europe
# 1769     zhwiki|plwiki|euwiki|eswiki|afwiki|ocwiki|huwi...    Europe
# ...                                                    ...       ...
# 2289106  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...    Europe
# 2289464  afwiki|alswiki|amwiki|arwiki|arzwiki|astwiki|a...    Europe
# 2289600  enwiki|dewiki|frwiki|eswiki|ruwiki|jawiki|nlwi...   America
# 2291069  afwiki|anwiki|frpwiki|bclwiki|bswiki|brwiki|ca...   America
# 2291242  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...    Europe
#
#         group_wikipedia_editions      bplo1       dplo1      bpla1      dpla1  \
# 174                          grA  69.604721   77.214333  21.642500  28.601860
# 1232                         grA -95.937500 -118.243683  41.258610  34.052231
# 1257                         grA -79.783356  -77.020790  40.546432  39.002441
# 1699                         grA   3.208889         NaN  39.570000        NaN
# 1769                         grA   0.196944         NaN  48.004166        NaN
# ...                          ...        ...         ...        ...        ...
# 2289106                      grA  19.500000   12.456388  49.883335  41.903610
# 2289464                      grA  37.611946   30.316668  55.783611  59.950001
# 2289600                      grA -96.557503  -77.029999  33.749699  38.974998
# 2291069                      grA -89.785301 -118.447777  41.630600  34.083328
# 2291242                      grA  37.617779   37.617779  55.755833  55.755833
#
#          pantheon_1                                     level3_all_occ  \
# 174               1  D:_politician_barrister_writer_journalist_phil...
# 1232              1  D:_actor_actor_choreographer_singer_dancer_fil...
# 1257              1  D:_biologist_environmentalist_zoologist_essayi...
# 1699              1  D:_player_model_P:_tennis_player_tennis_Englis...
# 1769              1  D:_politician_lawyer_legislative_P:_politician...
# ...             ...                                                ...
# 2289106           1  D:_priest_poet_politician_esperantist_writer_a...
# 2289464           1  D:_translator_poet_novelist_essayist_writer_jo...
# 2289600           1  D:_politician_writer_officer_statesperson_P:_ ...
# 2291069           1  D:_actor_actor_politician_biographer_actor_scr...
# 2291242           1  D:_physicist_activist_P:_physicist_dissident_a...
#
#         date_of_birth
# 174        1869-10-02
# 1232       1899-05-10
# 1257       1907-05-27
# 1699       1986-06-03
# 1769       1954-03-04
# ...               ...
# 2289106    1920-05-18
# 2289464
# 2289600    1890-10-14
# 2291069    1911-02-06
# 2291242    1921-05-21
#
# [2000 rows x 50 columns]

# %%
henry_III = client.get('Q53448')

# %%
henry_III.description
# Out:
# m'King of France from 1574 to 1589'

# %%
henry_III.attributes["claims"]
# Out:
# {'P39': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P39',
#     'hash': '10bba1d624b6e568d675cbe954f35d750ed86fce',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 18384454,
#       'id': 'Q18384454'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P580': [{'snaktype': 'value',
#       'property': 'P580',
#       'hash': '03faea1ccd949d0230882de0a5180cedd1518fef',
#       'datavalue': {'value': {'time': '+1574-06-09T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P582': [{'snaktype': 'value',
#       'property': 'P582',
#       'hash': 'aaa59ac44220318e79c79bca3569397a248456af',
#       'datavalue': {'value': {'time': '+1589-08-02T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P1365': [{'snaktype': 'value',
#       'property': 'P1365',
#       'hash': '2f416504581e98407009a06abe57ea3543d95322',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 134309,
#         'id': 'Q134309'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}],
#     'P1366': [{'snaktype': 'value',
#       'property': 'P1366',
#       'hash': '1acea568f3cf913fca2608780d458073a928d283',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 936976,
#         'id': 'Q936976'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P580', 'P582', 'P1365', 'P1366'],
#    'id': 'Q53448$de471744-457a-b77c-d125-28c8d67fe683',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P39',
#     'hash': '03ed92a1cde6e15a24ec0b21201071e687d8f239',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 3273712,
#       'id': 'Q3273712'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P580': [{'snaktype': 'value',
#       'property': 'P580',
#       'hash': 'd3f5f86188d7344dc2e349e7e484985c96ebadb6',
#       'datavalue': {'value': {'time': '+1573-05-11T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P582': [{'snaktype': 'value',
#       'property': 'P582',
#       'hash': '50ff7fc829d625e47eb067c7fc25678376037b18',
#       'datavalue': {'value': {'time': '+1574-06-18T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P1365': [{'snaktype': 'value',
#       'property': 'P1365',
#       'hash': '73e7da842c52fd1ae5a07f3310bdde9cebe563a7',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 54058,
#         'id': 'Q54058'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}],
#     'P1366': [{'snaktype': 'value',
#       'property': 'P1366',
#       'hash': 'c77b3024e3b2a25caffdd9fde4a20e0becab118c',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 233989,
#         'id': 'Q233989'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P580', 'P582', 'P1365', 'P1366'],
#    'id': 'Q53448$3CACE9FC-EF70-4928-8C4A-26AB6C6B9403',
#    'rank': 'normal',
#    'references': [{'hash': '14d2400e3b1d36332748dc330276f099eeaa8800',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '39224a9c2e8ce5424defbd16603d25771956c7fc',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 1551807,
#           'id': 'Q1551807'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P39',
#     'hash': 'f2b5030216013514a77a20325cf7b264caa8edb1',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 21095876,
#       'id': 'Q21095876'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$7e5b6fff-42b7-7d2b-8f9d-084b8013e536',
#    'rank': 'normal'}],
#  'P22': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P22',
#     'hash': '1737b1c7eb016e14196c0d01e433ae1b38c5747c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 132545,
#       'id': 'Q132545'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'q53448$4DB209DE-DDA4-4F30-8721-98B529C36B6F',
#    'rank': 'normal',
#    'references': [{'hash': 'e6596ed0d2b81634d4a2b94f1bd23a5d26a198cf',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '95e91ae0fae69e67febc1b579f0235e4fd3ee8dd',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 75653886,
#           'id': 'Q75653886'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P248']}]}],
#  'P25': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P25',
#     'hash': '74e926883256cc3153e6913dd3e842eb7c9fba60',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 131552,
#       'id': 'Q131552'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'q53448$0F344056-B7C7-4619-998B-4A17B6C444B1',
#    'rank': 'normal',
#    'references': [{'hash': 'e6596ed0d2b81634d4a2b94f1bd23a5d26a198cf',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '95e91ae0fae69e67febc1b579f0235e4fd3ee8dd',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 75653886,
#           'id': 'Q75653886'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P248']}]}],
#  'P19': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P19',
#     'hash': 'ce7b407a93eceec0f73a9afc575582aeafd39009',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 201428,
#       'id': 'Q201428'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'q53448$D82185AF-9F69-4213-AFB8-762DA7A71A3D',
#    'rank': 'normal'}],
#  'P26': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P26',
#     'hash': '6b594f38b3cd7bbec0561450d5bbc5c57b85884c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 225411,
#       'id': 'Q225411'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P580': [{'snaktype': 'value',
#       'property': 'P580',
#       'hash': '31460819c840f5c61fc7b7c1cdcf71b4c8bb7492',
#       'datavalue': {'value': {'time': '+1575-02-15T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P582': [{'snaktype': 'value',
#       'property': 'P582',
#       'hash': 'aaa59ac44220318e79c79bca3569397a248456af',
#       'datavalue': {'value': {'time': '+1589-08-02T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}]},
#    'qualifiers-order': ['P580', 'P582'],
#    'id': 'q53448$1E2A1450-F09D-46F4-B074-40E8FA9FBBF8',
#    'rank': 'normal',
#    'references': [{'hash': '16667929febdf6e0f287ca6e7f668a0bac915d55',
#      'snaks': {'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '76309133a092dd12826a44691d03ac2ccbdfbb74',
#         'datavalue': {'value': {'time': '+2016-01-20T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}],
#       'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'e541b5bb5fe30b73b12509931334d91cdec4461e',
#         'datavalue': {'value': 'http://genealogy.euweb.cz/lorraine/lorraine4.html',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P813', 'P854']},
#     {'hash': '39f614201fa522ab35eca5a425e1af53c0359f2e',
#      'snaks': {'P4638': [{'snaktype': 'value',
#         'property': 'P4638',
#         'hash': 'a4669ab3476f22dfc1c386d0c71738ea09e7ea73',
#         'datavalue': {'value': 'p10317.htm#i103163', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'e2b008912fe31b38fa64992d832ce82b9cf32f6f',
#         'datavalue': {'value': {'time': '+2020-08-07T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P4638', 'P813']},
#     {'hash': 'e6596ed0d2b81634d4a2b94f1bd23a5d26a198cf',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '95e91ae0fae69e67febc1b579f0235e4fd3ee8dd',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 75653886,
#           'id': 'Q75653886'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P248']}]}],
#  'P119': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P119',
#     'hash': 'd21a3279771da819006a464c35ef995a994eb316',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 184407,
#       'id': 'Q184407'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'q53448$85910D60-8E62-483C-BF8B-BB6A12C90362',
#    'rank': 'normal'}],
#  'P244': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P244',
#     'hash': 'a477ae1783562d72b733e4a220ad463ae4cbf56f',
#     'datavalue': {'value': 'n50040026', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'q53448$05E63CEC-ABDE-4F8E-913A-70CD1E8A0C9D',
#    'rank': 'normal',
#    'references': [{'hash': 'a29a646602abf65105ed0f39a44231c962ece9ee',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'c6f1777471211df31724ac60175786f3872c83e9',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 177837,
#           'id': 'Q177837'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']},
#     {'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 48183,
#           'id': 'Q48183'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P373': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P373',
#     'hash': 'b07dab029440b7c46a6616714225ee8a2550cb8b',
#     'datavalue': {'value': 'Henry III of Poland and France', 'type': 'string'},
#     'datatype': 'string'},
#    'type': 'statement',
#    'id': 'q53448$DE4BF265-8971-4590-A725-CD3CCFCB6D95',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P214': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P214',
#     'hash': 'aacfc10a7b85442ff573617e7a48681772b03e70',
#     'datavalue': {'value': '5774506', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'q53448$23829C14-D347-495F-9BC6-91F1CF7B8DFD',
#    'rank': 'normal',
#    'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 48183,
#           'id': 'Q48183'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P227': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P227',
#     'hash': '856c6e8178fc0f0022a221ff680597af2ae12976',
#     'datavalue': {'value': '118773720', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'q53448$07F9F78F-F6DA-46F8-BFA4-91EEDEE72490',
#    'rank': 'normal',
#    'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 48183,
#           'id': 'Q48183'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P213': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P213',
#     'hash': 'e47d23f275bc92ce0fcf21502264c82a36d707cf',
#     'datavalue': {'value': '0000 0001 2319 7721', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'q53448$1D68B371-9D1B-4663-8114-E343E684CA95',
#    'rank': 'normal',
#    'references': [{'hash': 'fbc824608bf047fcbfb803c1b0f98e66f4372207',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'a376d605be64acdd4ac7934925ba96e276de7eac',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 423048,
#           'id': 'Q423048'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P248']}]}],
#  'P20': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P20',
#     'hash': '9a5450a6d7dbcf2ad44d07ca7cfc8d7264940d2a',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 189153,
#       'id': 'Q189153'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'q53448$8A0432D7-0A73-40FE-A9C5-D2A12AA70F32',
#    'rank': 'normal',
#    'references': [{'hash': '503c8b8879ebe3e0e1614b921627708c0b8228ca',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '019a50b7de741e0068bde41c9d9955b22a5de47b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 36578,
#           'id': 'Q36578'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'a5291b537a08b8087ccaaea3d6423b3ced6b8f48',
#         'datavalue': {'value': {'time': '+2014-12-30T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P813']}]}],
#  'P569': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P569',
#     'hash': 'bd06ff10dd15dc596adc0ada9673d870d05cb1fb',
#     'datavalue': {'value': {'time': '+1551-09-19T00:00:00Z',
#       'timezone': 0,
#       'before': 0,
#       'after': 0,
#       'precision': 11,
#       'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#      'type': 'time'},
#     'datatype': 'time'},
#    'type': 'statement',
#    'id': 'q53448$B859B44F-323B-414E-93BD-AB134487A762',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']},
#     {'hash': '0c775477f1705ad96be26ba5e2db9c013305819f',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '019a50b7de741e0068bde41c9d9955b22a5de47b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 36578,
#           'id': 'Q36578'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P227': [{'snaktype': 'value',
#         'property': 'P227',
#         'hash': '856c6e8178fc0f0022a221ff680597af2ae12976',
#         'datavalue': {'value': '118773720', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'd725f5a449709fcaa00d55c62793ac1447c9980f',
#         'datavalue': {'value': {'time': '+2015-08-14T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P227', 'P813']}]},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P569',
#     'hash': 'f3a3d7802ec18f95447859d133341ebe9e73b8cb',
#     'datavalue': {'value': {'time': '+1551-01-01T00:00:00Z',
#       'timezone': 0,
#       'before': 0,
#       'after': 0,
#       'precision': 9,
#       'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#      'type': 'time'},
#     'datatype': 'time'},
#    'type': 'statement',
#    'id': 'Q53448$3AA82D98-71DE-4FF2-80FE-1A5AB607612E',
#    'rank': 'normal'}],
#  'P570': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P570',
#     'hash': 'd978de327c8e62e2f40ad8b30bedcf72aec8d884',
#     'datavalue': {'value': {'time': '+1589-08-02T00:00:00Z',
#       'timezone': 0,
#       'before': 0,
#       'after': 0,
#       'precision': 11,
#       'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#      'type': 'time'},
#     'datatype': 'time'},
#    'type': 'statement',
#    'id': 'q53448$4D4588C3-E510-44D6-A314-79E344B4BCA0',
#    'rank': 'normal',
#    'references': [{'hash': 'abc9457dcf728dd069b8ed5b2e1a86035cf2b679',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '019a50b7de741e0068bde41c9d9955b22a5de47b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 36578,
#           'id': 'Q36578'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '7805df7373a5e95763e019b855686d24acee918e',
#         'datavalue': {'value': {'time': '+2014-04-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P813']},
#     {'hash': '561d3bee7938f93dc6ca95f06020bbcb94f63c47',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'b62f3fa8bab7eb5e1bfe16d03cda082d25315c85',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 63056,
#           'id': 'Q63056'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P535': [{'snaktype': 'value',
#         'property': 'P535',
#         'hash': '8a70025e00a4c16782e917f5c56a3a0abc4966f7',
#         'datavalue': {'value': '21078', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': 'd13c8aaded18b4b661d5f7281e0ecd17c4d25c02',
#         'datavalue': {'value': 'Henri III de France', 'type': 'string'},
#         'datatype': 'string'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#         'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P535', 'P1810', 'P813']},
#     {'hash': 'd28bb23abe7d260d62053e57d0246901ee3b209a',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'd1d1b10a05a8f3fc5d26bb4aeb6849617ad81fc7',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 5375741,
#           'id': 'Q5375741'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P1417': [{'snaktype': 'value',
#         'property': 'P1417',
#         'hash': '849608a5d340e03326a32d2ae643bfa7587997bf',
#         'datavalue': {'value': 'biography/Henry-III-king-of-France-and-Poland',
#          'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': 'a236c43f7133d84d28d2a3723295a3e2bb8edec0',
#         'datavalue': {'value': 'Henry III', 'type': 'string'},
#         'datatype': 'string'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#         'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P1417', 'P1810', 'P813']},
#     {'hash': '96b786518150b233217e7c26da15f134979c881c',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '2cb827dc711b8ec4594187170c0bce6d67f54fbe',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 21401824,
#           'id': 'Q21401824'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P4638': [{'snaktype': 'value',
#         'property': 'P4638',
#         'hash': 'a4669ab3476f22dfc1c386d0c71738ea09e7ea73',
#         'datavalue': {'value': 'p10317.htm#i103163', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '902cf80464933b68ad9e9fbc2dfd187fad38b282',
#         'datavalue': {'value': 'Henri III, Roi de France', 'type': 'string'},
#         'datatype': 'string'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#         'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P4638', 'P1810', 'P813']},
#     {'hash': 'b21d9f0940cf8f116ff8c095cc9a556e6f909ff1',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'e2a81dbf2f7dd02b332d6358ef65f622f82e8cc3',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 237227,
#           'id': 'Q237227'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P5019': [{'snaktype': 'value',
#         'property': 'P5019',
#         'hash': 'eeb7cd527812043a7fc4d96392a6ecd5cce106c4',
#         'datavalue': {'value': 'heinrich-heinrich-iii-20', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '61fa0f1546908c708dd150e0f205fdf5a45d4694',
#         'datavalue': {'value': 'Heinrich III. (Frankreich)', 'type': 'string'},
#         'datatype': 'string'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#         'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P5019', 'P1810', 'P813']},
#     {'hash': '10642e84511a6f05d625d49181bcb4b48125cda7',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '95e91ae0fae69e67febc1b579f0235e4fd3ee8dd',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 75653886,
#           'id': 'Q75653886'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P3051': [{'snaktype': 'value',
#         'property': 'P3051',
#         'hash': '749b2e2bf577fcd259fcf654e55bf321de2ce6ba',
#         'datavalue': {'value': 'I4018', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '1ed21b6cd6552cc0ca92e56262d7d88399334770',
#         'datavalue': {'value': 'Henry III [House of Capet; Valois-Angoulême]',
#          'type': 'string'},
#         'datatype': 'string'}]},
#      'snaks-order': ['P248', 'P3051', 'P1810']},
#     {'hash': '3140e28d3188ea565324d82043f12d5493b28ffb',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '52c431c41b8a73130ff729f9b7027b9d19fffcd5',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 2664168,
#           'id': 'Q2664168'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P1296': [{'snaktype': 'value',
#         'property': 'P1296',
#         'hash': 'a2e7c4fe2feb4bed5c920f392cf4148fcede995b',
#         'datavalue': {'value': '0024101', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': 'd3480a80721d1d8714d9c7e070b6a94274fc1deb',
#         'datavalue': {'value': 'Enric III de França', 'type': 'string'},
#         'datatype': 'string'}]},
#      'snaks-order': ['P248', 'P1296', 'P1810']},
#     {'hash': 'af62e3fc32c5ed7fa21750df0595f2428aa221f2',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'c83074f882f1a2a7745f87da83d469a187e887a5',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 96022943,
#           'id': 'Q96022943'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P8130': [{'snaktype': 'value',
#         'property': 'P8130',
#         'hash': 'ebbffdf3509f6e2c1dbf498aa5aff5b3630f9af0',
#         'datavalue': {'value': 'henryk-iii-walezy-krol-wiesz',
#          'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '62fec4184979131cba4728ee0594cd3089b563e7',
#         'datavalue': {'value': 'Henryk III Walezy', 'type': 'string'},
#         'datatype': 'string'}]},
#      'snaks-order': ['P248', 'P8130', 'P1810']},
#     {'hash': '3a168cd324206cba1a12ddd125b46ebe91527a66',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '18a7eccf050ab7390888344c498336e62366cbdb',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 19847326,
#           'id': 'Q19847326'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P1819': [{'snaktype': 'value',
#         'property': 'P1819',
#         'hash': 'aebfb9d2676f1de5fa1462bbf170eb0993c87179',
#         'datavalue': {'value': 'I00003805', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '34205795cb06b27baed434014a8fc88baebdff4c',
#         'datavalue': {'value': 'Henri III', 'type': 'string'},
#         'datatype': 'string'}]},
#      'snaks-order': ['P248', 'P1819', 'P1810']},
#     {'hash': '08d80940a2f904130d5863ceefc4cbd292aeb598',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '46c57705d3d830a83aa228de72dc7c148cd30551',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 3407324,
#           'id': 'Q3407324'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P8349': [{'snaktype': 'value',
#         'property': 'P8349',
#         'hash': '2d14642b17b584b1d37280e7b1106c59cde20fdd',
#         'datavalue': {'value': '26029', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': 'b3422272f6fbd7f78591d758e81611b1095763a9',
#         'datavalue': {'value': 'Henrik III.', 'type': 'string'},
#         'datatype': 'string'}]},
#      'snaks-order': ['P248', 'P8349', 'P1810']},
#     {'hash': 'beeda45be18aede817929a251a48f5fba82b625a',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '3955d0a7521fe2bf1f954efaaa995dc5c1aab2a1',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 1789619,
#           'id': 'Q1789619'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P7982': [{'snaktype': 'value',
#         'property': 'P7982',
#         'hash': '2b7092c00e674eceec2029ddc929945bb5efd9ce',
#         'datavalue': {'value': '25013', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '48e9f90864400503bc7b7297e83fbec00e8a1ad1',
#         'datavalue': {'value': 'Henrik III. (francuski kralj)',
#          'type': 'string'},
#         'datatype': 'string'}]},
#      'snaks-order': ['P248', 'P7982', 'P1810']},
#     {'hash': 'b976c643560b6215207fe7654d0d19f9b85a51fb',
#      'snaks': {'P5375': [{'snaktype': 'value',
#         'property': 'P5375',
#         'hash': '4ee9a3ba43c663c7d49ff1dc7ffb3a87e735e72e',
#         'datavalue': {'value': '17085', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P1810': [{'snaktype': 'value',
#         'property': 'P1810',
#         'hash': '34205795cb06b27baed434014a8fc88baebdff4c',
#         'datavalue': {'value': 'Henri III', 'type': 'string'},
#         'datatype': 'string'}],
#       'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '0bde68953160e94daaa581d877970796760d2ec8',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 105958830,
#           'id': 'Q105958830'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P5375', 'P1810', 'P248']}]},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P570',
#     'hash': '50b5faed7f3730db904ae132b7607d8692da192d',
#     'datavalue': {'value': {'time': '+1589-01-01T00:00:00Z',
#       'timezone': 0,
#       'before': 0,
#       'after': 0,
#       'precision': 9,
#       'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#      'type': 'time'},
#     'datatype': 'time'},
#    'type': 'statement',
#    'id': 'Q53448$A3F5B464-E4F8-4E9A-AB2C-632238B78DAB',
#    'rank': 'normal'}],
#  'P31': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P31',
#     'hash': 'ad7d38a03cdd40cdc373de0dc4e7b7fcbccb31d9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 5,
#       'id': 'Q5'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$B2AFF98D-0103-4C12-BED2-7468426793E0',
#    'rank': 'normal',
#    'references': [{'hash': '16667929febdf6e0f287ca6e7f668a0bac915d55',
#      'snaks': {'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '76309133a092dd12826a44691d03ac2ccbdfbb74',
#         'datavalue': {'value': {'time': '+2016-01-20T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}],
#       'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'e541b5bb5fe30b73b12509931334d91cdec4461e',
#         'datavalue': {'value': 'http://genealogy.euweb.cz/lorraine/lorraine4.html',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P813', 'P854']}]}],
#  'P646': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P646',
#     'hash': 'd66c325221aac71fff0e78ba1b7ff1a9ed06c492',
#     'datavalue': {'value': '/m/0k2mp', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$40818BE8-8295-459A-BC65-7E826DD543B8',
#    'rank': 'normal',
#    'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 15241312,
#           'id': 'Q15241312'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P577': [{'snaktype': 'value',
#         'property': 'P577',
#         'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#         'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P577']}]}],
#  'P906': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P906',
#     'hash': '9beda9314047676dfb27ab54516ba0bcf0fd1b05',
#     'datavalue': {'value': '60400', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$2A3607D4-91E5-4FF6-99E5-91DE2F35F695',
#    'rank': 'normal',
#    'references': [{'hash': '14d2400e3b1d36332748dc330276f099eeaa8800',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '39224a9c2e8ce5424defbd16603d25771956c7fc',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 1551807,
#           'id': 'Q1551807'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P268': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P268',
#     'hash': 'da78402663e2c990f4df440da704f4057f9cbdee',
#     'datavalue': {'value': '12016877w', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$78845A4D-2393-4A0B-8815-2B8BE68AB897',
#    'rank': 'normal'}],
#  'P18': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P18',
#     'hash': '10c05604be5fa181862c820d977237a79f0e83de',
#     'datavalue': {'value': 'France-001615 - King Henri III (15291221709) (2).jpg',
#      'type': 'string'},
#     'datatype': 'commonsMedia'},
#    'type': 'statement',
#    'id': 'Q53448$7099B166-3B31-441F-8D2F-C2F582E50F84',
#    'rank': 'normal',
#    'references': [{'hash': 'd4bd87b862b12d99d26e86472d44f26858dee639',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'f30cbd35620c4ea6d0633aaf0210a8916130469b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 8447,
#           'id': 'Q8447'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P53': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P53',
#     'hash': '7cd391ab1188abfaaa3b3467238643014b1177c9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 182135,
#       'id': 'Q182135'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$BF51CD17-9350-40B7-BA25-4EFD279EDFC4',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P109': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P109',
#     'hash': '72a7ee90da150116deb8c28fe054d5aadd80b9b4',
#     'datavalue': {'value': 'Signature of Henry III Valois as King of Poland.PNG',
#      'type': 'string'},
#     'datatype': 'commonsMedia'},
#    'type': 'statement',
#    'id': 'Q53448$F8D2ECA2-75F7-4EF6-A494-ECAAFA7547F6',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P27': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P27',
#     'hash': 'cb394c273485ea66ee9aa0ae2cea019e016c41fe',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 70972,
#       'id': 'Q70972'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$404B521A-2A15-4695-A099-BEED46D25620',
#    'rank': 'normal'}],
#  'P97': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P97',
#     'hash': '581f1111c02332acf7433bf8342bb8fe05a2ab7d',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 2639920,
#       'id': 'Q2639920'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$CADC0A65-9957-4047-B8D2-571035A84F0A',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P97',
#     'hash': '505978fa547391d83f13501ee4069f965606894f',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 18384454,
#       'id': 'Q18384454'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$5159367f-4825-a39e-0f43-d6f8f05d55c7',
#    'rank': 'normal'}],
#  'P1273': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1273',
#     'hash': '3693db987fdb4ab2d903baa1164070cc026047e0',
#     'datavalue': {'value': 'a11371626', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$E4095AF9-6042-4D94-9300-D1FA8D76DDC5',
#    'rank': 'normal',
#    'references': [{'hash': '212eac4fc40236243694a2cb6ab8ef846c796c24',
#      'snaks': {'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': '18eed8bbd49eaf2f01e9c52c6662d7c378afb36f',
#         'datavalue': {'value': 'https://viaf.org/viaf/5774506/',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P854']}]}],
#  'P1207': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1207',
#     'hash': '8b5442e800a9edb00ed7ba5e28b0d501c38ad2ea',
#     'datavalue': {'value': 'n98004315', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$6B594AC6-D7EF-47CF-B9F4-E8644B5DAA95',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P1207',
#     'hash': '4b3a939d028e4e5ec3cf587e684a514d85c0046a',
#     'datavalue': {'value': 'n99008096', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$9174A22E-8B55-4195-8B0D-D5FA2BEA8C8F',
#    'rank': 'normal'}],
#  'P443': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P443',
#     'hash': '94964e1b358c5eb5fa59ab0bf95134a164e32d47',
#     'datavalue': {'value': 'Pl-Henryk-Walezy.ogg', 'type': 'string'},
#     'datatype': 'commonsMedia'},
#    'type': 'statement',
#    'qualifiers': {'P407': [{'snaktype': 'value',
#       'property': 'P407',
#       'hash': 'b9b821e8a9140ec208fb522e0aa113d5742f6fba',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 809,
#         'id': 'Q809'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P407'],
#    'id': 'Q53448$43040857-4b73-9dcc-2170-c49de0c41225',
#    'rank': 'normal'}],
#  'P1006': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1006',
#     'hash': 'e040200082d0cda5d9ae737cd9ba0c321c9d758d',
#     'datavalue': {'value': '070548552', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$C448C444-9584-4364-8464-6D78981847E1',
#    'rank': 'normal'}],
#  'P269': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P269',
#     'hash': 'bb98807880a761d2275df1d1c8527abdc577b734',
#     'datavalue': {'value': '028305558', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$9F19C2C1-85CF-42B9-B1E6-ADC0A99574E6',
#    'rank': 'normal'}],
#  'P409': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P409',
#     'hash': 'ec3b4ec0bc3386356cc92c65cca8b007044c1695',
#     'datavalue': {'value': '35187797', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$791BAE4C-5041-40CF-AE56-B3D602B42C76',
#    'rank': 'normal'}],
#  'P1017': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1017',
#     'hash': '9075f75137a19873da600d6c3b8aedb432c1c26d',
#     'datavalue': {'value': 'ADV10171158', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$CDCF855A-B8F8-4F36-9AAD-2BA775A47A5A',
#    'rank': 'normal'}],
#  'P910': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P910',
#     'hash': '2b6099bb561c4f729bb47bb2f8aaab5f73dfa0b9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16806609,
#       'id': 'Q16806609'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$060de76e-4686-fab8-6402-3ac053567089',
#    'rank': 'normal'}],
#  'P735': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P735',
#     'hash': '6b176ac816a8642889be3776683ffbf35926e9ba',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 1605665,
#       'id': 'Q1605665'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P7338': [{'snaktype': 'value',
#       'property': 'P7338',
#       'hash': '425aac845deebd97ac6c037be2f0adc816312be6',
#       'datavalue': {'value': 'III', 'type': 'string'},
#       'datatype': 'string'}],
#     'P3831': [{'snaktype': 'value',
#       'property': 'P3831',
#       'hash': '76b85af6dcc8c934c6cff2370cef3deaa6749300',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 105636992,
#         'id': 'Q105636992'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}],
#     'P580': [{'snaktype': 'value',
#       'property': 'P580',
#       'hash': '6c04e8ead71650f373cc0756ace480f80ce78223',
#       'datavalue': {'value': {'time': '+1565-03-17T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#        'type': 'time'},
#       'datatype': 'time'}]},
#    'qualifiers-order': ['P7338', 'P3831', 'P580'],
#    'id': 'Q53448$07715D51-6A91-4B03-A50A-E931FB6B5F29',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P735',
#     'hash': '6dde8a04dd8979d6abb729d6aafca5e4d3f44e44',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 221774,
#       'id': 'Q221774'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P1545': [{'snaktype': 'value',
#       'property': 'P1545',
#       'hash': '7241753c62a310cf84895620ea82250dcea65835',
#       'datavalue': {'value': '2', 'type': 'string'},
#       'datatype': 'string'}],
#     'P3831': [{'snaktype': 'value',
#       'property': 'P3831',
#       'hash': '72b0eecdeb0564ec238e4869eedaf6fbce92a07e',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 2507958,
#         'id': 'Q2507958'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P1545', 'P3831'],
#    'id': 'Q53448$8d6bc9b4-469c-2e2a-a380-00d2d0c6d6eb',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P735',
#     'hash': '4a2e8e9de7aa412abbf96f2a947a95ff2bd4dc24',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16002466,
#       'id': 'Q16002466'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P1545': [{'snaktype': 'value',
#       'property': 'P1545',
#       'hash': '2a1ced1dca90648ea7e306acbadd74fc81a10722',
#       'datavalue': {'value': '1', 'type': 'string'},
#       'datatype': 'string'}],
#     'P3831': [{'snaktype': 'value',
#       'property': 'P3831',
#       'hash': '72b0eecdeb0564ec238e4869eedaf6fbce92a07e',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 2507958,
#         'id': 'Q2507958'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P1545', 'P3831'],
#    'id': 'Q53448$63bc3413-40c5-5fde-7c19-de421c23e115',
#    'rank': 'normal'}],
#  'P1263': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1263',
#     'hash': 'e1db33485b91f4f40f06733a2d3444962e77b51b',
#     'datavalue': {'value': '842/000093563', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$D4C6CED4-B0DE-4ABC-865F-22EA88F9BF3B',
#    'rank': 'normal'}],
#  'P1802': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1802',
#     'hash': '46c72acfab86baa00033f93cd4796434d0b51c97',
#     'datavalue': {'value': 'caef8c22-516a-47ec-9416-d717dc392842',
#      'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$267D85F8-1E65-4FAC-BDED-235B61FE1F9F',
#    'rank': 'normal'}],
#  'P1196': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1196',
#     'hash': '7412b6b6a087b816646760aca992034d6ed103e5',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 149086,
#       'id': 'Q149086'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P805': [{'snaktype': 'value',
#       'property': 'P805',
#       'hash': 'd5349322a47f997c8c745e63297bd89c75716c6a',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 60836405,
#         'id': 'Q60836405'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P805'],
#    'id': 'Q53448$D33A293F-ADF5-4B82-B5EF-3C4FE9864135',
#    'rank': 'normal'}],
#  'P140': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P140',
#     'hash': '1d37cef459ae3310e8856a343b4f5d0ceaee71e2',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 1841,
#       'id': 'Q1841'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$5C6D6094-7A7B-4598-9F29-AF2525AE8007',
#    'rank': 'normal'}],
#  'P509': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P509',
#     'hash': '8c8d79a08a3c845a8ad53087800cf709843f8f87',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 4228595,
#       'id': 'Q4228595'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q53448$263FB4F8-6E8E-4B60-B58F-DEA80FEE391B',
#    'rank': 'normal'}],
#  'P1343': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1343',
#     'hash': '42346dfe9209b7359c1f5db829a368b38d407797',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 19180675,
# ...
#       'hash': '74bd46d0bbe97d05804856f1f73b6a7480c68cec',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 45403344,
#         'id': 'Q45403344'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P2241'],
#    'id': 'Q53448$B7C6C106-8DBF-4C64-A2ED-C270108369D4',
#    'rank': 'deprecated'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P4342',
#     'hash': 'b335149287db8bf6426dd0ebbd629cf650c6ca3c',
#     'datavalue': {'value': 'Henrik_3_-_konge_av_Frankrike', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'qualifiers': {'P2241': [{'snaktype': 'value',
#       'property': 'P2241',
#       'hash': '74bd46d0bbe97d05804856f1f73b6a7480c68cec',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 45403344,
#         'id': 'Q45403344'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P2241'],
#    'id': 'Q53448$52b61d72-4bba-d718-4e39-e388b1e7400e',
#    'rank': 'deprecated'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P4342',
#     'hash': '07822cfc192fcf596e63d4b57c0ce7b039136834',
#     'datavalue': {'value': 'Henrik_3._-_konge_av_Frankrike', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$5896aabf-1b10-4773-8f87-31ae03f50464',
#    'rank': 'normal'}],
#  'P6327': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P6327',
#     'hash': 'f76a87b6cc9f555f4b2a6e9f9f88ad984ec3a7ff',
#     'datavalue': {'value': '44824', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$5B6DDC51-A23F-49D1-A51C-CE0B5B78B94B',
#    'rank': 'normal'}],
#  'P2600': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P2600',
#     'hash': '29adacb9a3e7138b070c9ffb4501172cb2f5ab45',
#     'datavalue': {'value': '6000000000307280073', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$BAF55A20-ECA7-474F-B5A2-2A8E26A0E22F',
#    'rank': 'normal'}],
#  'P5504': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P5504',
#     'hash': '0e709cc532f42cc42fc5f47d0778e7a90384c7ce',
#     'datavalue': {'value': 'pe347122', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$CA61C6D6-C249-4F0C-9455-F77A6AA0755A',
#    'rank': 'normal'}],
#  'P8179': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P8179',
#     'hash': '041ce986e693a2f4252d3035c043f7b0f0a1eebc',
#     'datavalue': {'value': 'ncf12076087', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'q53448$6ffaef68-4432-1539-cc98-ed73ccfd039a',
#    'rank': 'normal',
#    'references': [{'hash': '9dd077750f31b861ed8981d0e5a6a16ffe6e33fb',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 54919,
#           'id': 'Q54919'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P214': [{'snaktype': 'value',
#         'property': 'P214',
#         'hash': 'aacfc10a7b85442ff573617e7a48681772b03e70',
#         'datavalue': {'value': '5774506', 'type': 'string'},
#         'datatype': 'external-id'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': 'aa2ec202b8eee640803c9a28629a8086671dafe2',
#         'datavalue': {'value': {'time': '+2021-04-22T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P214', 'P813']}]}],
#  'P9371': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P9371',
#     'hash': '02150722f251e8313fab57c08dd12f38c13d3a04',
#     'datavalue': {'value': '130736800', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$AB38C88F-CDA3-4F9B-9735-A0D0A0AED325',
#    'rank': 'normal'}],
#  'P1185': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1185',
#     'hash': 'bc125b5e5ae91b4939c44949d30ea0a1e12f6b8b',
#     'datavalue': {'value': '29473', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$1AFC85F1-4558-4B2C-82DE-8A6F0C0FB586',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P1185',
#     'hash': '17a3252a80df863925dfe5d2b90f579fd1d2b2f1',
#     'datavalue': {'value': '505373', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$2e4bc1c7-bcb0-40b0-9897-2df92d272c6a',
#    'rank': 'normal'}],
#  'P7929': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P7929',
#     'hash': 'db862db68a423aaf55a9d9286169f72492404c46',
#     'datavalue': {'value': 'p=edouard alexandre;n=d angouleme',
#      'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$2CEFCBE5-3FC6-4C39-9B7B-8A9DF5A28997',
#    'rank': 'normal'}],
#  'P9756': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P9756',
#     'hash': '5bd3d95cf3db34e96c08e6be75770c1ccfe98ea9',
#     'datavalue': {'value': '1614', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$95781606-CA68-45FB-AC87-7D92DFD4C9F4',
#    'rank': 'normal'}],
#  'P7305': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P7305',
#     'hash': '6f1c7dd861964b3478459b6bd29c2d7f2a4ff9d9',
#     'datavalue': {'value': '3911072', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'qualifiers': {'P1810': [{'snaktype': 'value',
#       'property': 'P1810',
#       'hash': '62fec4184979131cba4728ee0594cd3089b563e7',
#       'datavalue': {'value': 'Henryk III Walezy', 'type': 'string'},
#       'datatype': 'string'}]},
#    'qualifiers-order': ['P1810'],
#    'id': 'Q53448$0bd9361d-41f1-95ba-b0ce-efaf2a0762d9',
#    'rank': 'normal',
#    'references': [{'hash': '53bcc28c9e40c8ad4c6965114a8e1ca08f47adeb',
#      'snaks': {'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'e843b2d8a80306c4fadf5c0cd10bec0334e2221d',
#         'datavalue': {'value': 'https://encyklopedia.pwn.pl/haslo/Henryk-III-Walezy;3911072.html',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P854']}]}],
#  'P3365': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P3365',
#     'hash': '799f4639ff1fb5da2be88509becf479e65e00a75',
#     'datavalue': {'value': 'enrico-iii-re-di-francia-e-di-polonia',
#      'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'qualifiers': {'P1810': [{'snaktype': 'value',
#       'property': 'P1810',
#       'hash': 'f6e5ee2fe53a238b4273ce0de4fe05465972d052',
#       'datavalue': {'value': 'Enrico III re di Francia e di Polonia',
#        'type': 'string'},
#       'datatype': 'string'}]},
#    'qualifiers-order': ['P1810'],
#    'id': 'Q53448$7a69a187-46a9-638f-1b89-7737fbc02bff',
#    'rank': 'normal',
#    'references': [{'hash': 'cb2c754afc93b3781ae20df93426bbeb3d5dc44b',
#      'snaks': {'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'c323d198e7e02bae40753a8ee85d7bb05c4e2ca6',
#         'datavalue': {'value': 'https://www.treccani.it/enciclopedia/enrico-iii-re-di-francia-e-di-polonia',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P854']},
#     {'hash': '4c93d46ecc6737764dbb37d1f5ec0aca36082494',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '4706edc1769bf829cb25d25e5fe311c75e3853a2',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 65921422,
#           'id': 'Q65921422'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '83943bb885eb1f30579e2c290348f47a3e8577ed',
#         'datavalue': {'value': {'time': '+2022-04-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P813']}]}],
#  'P9984': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P9984',
#     'hash': 'cd17506980ac1e214d970bd3945d74916b1e8b30',
#     'datavalue': {'value': '981058512315706706', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$BEE3C1D1-95BB-48C1-BB1A-76DF0BF76B6E',
#    'rank': 'normal'}],
#  'P10242': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P10242',
#     'hash': '9db2b2822329451a619e59cc5c9fbe92cee3415d',
#     'datavalue': {'value': '01779/eu_e_1704/e1704', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'qualifiers': {'P1932': [{'snaktype': 'value',
#       'property': 'P1932',
#       'hash': '2b7af04ad749fb536d7d87b288fb84f83d28b631',
#       'datavalue': {'value': 'Henrike IIIa Frantziakoa', 'type': 'string'},
#       'datatype': 'string'}]},
#    'qualifiers-order': ['P1932'],
#    'id': 'Q53448$AFCE7EC2-52D6-4F40-A0DC-4A16F837FE7B',
#    'rank': 'normal'}],
#  'P6385': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P6385',
#     'hash': 'd25e892107eb39ea3400a5c271f20558209e8b88',
#     'datavalue': {'value': 'istoriya/GENRIH_III.html', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$8ac3a385-478e-ef3a-267d-2158bf544be0',
#    'rank': 'normal'}],
#  'P8313': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P8313',
#     'hash': '201444b470b9aaad712037278076cb36458f4682',
#     'datavalue': {'value': 'Henrik_3._-_konge_af_Polen_og_af_Frankrig',
#      'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$7D54BD4D-314E-46F0-A7CD-81D2948D1D87',
#    'rank': 'normal'}],
#  'P3222': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P3222',
#     'hash': 'a3e28bb1fe2bf2e2b1ea54605cec86f7e2cc746a',
#     'datavalue': {'value': 'henrik-iii', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$226e6062-43d7-fecf-0c9c-d95f7dcfac92',
#    'rank': 'normal'}],
#  'P9507': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P9507',
#     'hash': '467b63d57108309a9453a53de9bb73e9bcf759c4',
#     'datavalue': {'value': '2661', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$D2F4F0EE-4E07-4F17-B64D-65BD935C20B3',
#    'rank': 'normal'}],
#  'P10480': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P10480',
#     'hash': '5452bb7c6f9f6d91d99295a316bd3626db66e214',
#     'datavalue': {'value': 'Actr46889', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$EE0F12C1-1F9B-4D68-8C8C-B9BD471BB7F8',
#    'rank': 'normal'}],
#  'P10141': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P10141',
#     'hash': '1614e6c9139b680c3459355458ab484b77b36bd6',
#     'datavalue': {'value': '34286', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$B54EAC07-B70C-4306-AA8D-269608D8583B',
#    'rank': 'normal'}],
#  'P4223': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P4223',
#     'hash': '849259def9ccfaeefdba7c3dc1ff5552239da22b',
#     'datavalue': {'value': 'enrico-iii-re-di-francia', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'qualifiers': {'P577': [{'snaktype': 'value',
#       'property': 'P577',
#       'hash': 'bc61f6f80f347571e76e6427a376da17ad63826d',
#       'datavalue': {'value': {'time': '+1932-01-01T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 9,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P2093': [{'snaktype': 'value',
#       'property': 'P2093',
#       'hash': '202725485292722bd0bc2df6061ff5cdb1165237',
#       'datavalue': {'value': 'Rosario Russo', 'type': 'string'},
#       'datatype': 'string'}],
#     'P1810': [{'snaktype': 'value',
#       'property': 'P1810',
#       'hash': 'cda3c13b5030e8a09b1ff6eae855683e874abcaf',
#       'datavalue': {'value': 'ENRICO III re di Francia', 'type': 'string'},
#       'datatype': 'string'}]},
#    'qualifiers-order': ['P577', 'P2093', 'P1810'],
#    'id': 'Q53448$6D1170A9-3581-4DD6-84FC-0192151CA5F5',
#    'rank': 'normal',
#    'references': [{'hash': 'de540cb7dc860e73aa2c6485f584d519502b55c5',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '34eeda6017137fe962f181714ee5f1ed649a7cc6',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 731361,
#           'id': 'Q731361'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '83943bb885eb1f30579e2c290348f47a3e8577ed',
#         'datavalue': {'value': {'time': '+2022-04-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P813']}]}],
#  'P10553': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P10553',
#     'hash': 'af76207becf4497eeed8b4075294d2e2bcdc127a',
#     'datavalue': {'value': '079552838', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$50971D5A-7DA8-4650-995D-5CAE4490CE5F',
#    'rank': 'normal'}],
#  'P10864': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P10864',
#     'hash': 'd9a8ef096dd1ac4e3fdee113851ad818ab313e96',
#     'datavalue': {'value': '3373', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$36C7B269-5720-41DC-A5EA-24AFC472F21A',
#    'rank': 'normal'}],
#  'P11249': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P11249',
#     'hash': '7beb7830cd1592583853f2537b80c1220ae394ae',
#     'datavalue': {'value': '14806084', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$CED204CD-C146-4A27-93D8-C2C536F69B81',
#    'rank': 'normal'}],
#  'P11686': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P11686',
#     'hash': '18826db5e9712a57e10f4ea12b93e7e5d492f52d',
#     'datavalue': {'value': '981058512315706706', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$BE7A558C-62E8-428C-9556-6D89C1D5A6B2',
#    'rank': 'normal'}],
#  'P11835': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P11835',
#     'hash': '5fbb1d9f54d2745735a0b09ee393568bc2551e45',
#     'datavalue': {'value': '1154', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$1300BA4F-7CD7-4DA4-8DC8-F1BE69DF732C',
#    'rank': 'normal'}],
#  'P9943': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P9943',
#     'hash': '978216b8f6474935384f47c215953ba031b79ac5',
#     'datavalue': {'value': 'person/707858758487', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$BAA96F56-2167-486C-A328-0E20F1736DED',
#    'rank': 'normal',
#    'references': [{'hash': 'bcd583d9eb8a31aca77df9be9b452c3eadddb3de',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'f98f2377ab32ebb5ee142ac24dbf49427ad1bee9',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 108895273,
#           'id': 'Q108895273'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P248']}]}],
#  'P11514': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P11514',
#     'hash': '15cf1e719eb1e5411bb746f05c2273a6f10f9e32',
#     'datavalue': {'value': 'genrikh-iii-korol-frantsii-cee1aa',
#      'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q53448$A242B574-468E-4649-A78C-F05B5D96EAD1',
#    'rank': 'normal'}]}

# %%
date_of_birth = client.get('P569')

# %%
henry_III[date_of_birth]
# Out:
# ---------------------------------------------------------------------------
# DatavalueError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 henry_III[date_of_birth]
#
# File ~/anaconda3/lib/python3.11/site-packages/wikidata/entity.py:179, in Entity.__getitem__(self, key)
#     178 def __getitem__(self, key: 'Entity') -> object:
# --> 179     result = self.getlist(key)
#     180     if result:
#     181         return result[0]
#
# File ~/anaconda3/lib/python3.11/site-packages/wikidata/entity.py:208, in Entity.getlist(self, key)
#     206     logger.debug('claim data: %s', pprint.pformat(claims))
#     207 decode = self.client.decode_datavalue
# --> 208 return [decode(snak['datatype'], snak['datavalue'])
#     209         for snak in (claim['mainsnak'] for claim in claims)
#     210         if snak['snaktype'] == 'value']
#
# File ~/anaconda3/lib/python3.11/site-packages/wikidata/entity.py:208, in <listcomp>(.0)
#     206     logger.debug('claim data: %s', pprint.pformat(claims))
#     207 decode = self.client.decode_datavalue
# --> 208 return [decode(snak['datatype'], snak['datavalue'])
#     209         for snak in (claim['mainsnak'] for claim in claims)
#     210         if snak['snaktype'] == 'value']
#
# File ~/anaconda3/lib/python3.11/site-packages/wikidata/client.py:179, in Client.decode_datavalue(self, datatype, datavalue)
#     171 """Decode the given ``datavalue`` using the configured
#     172 :attr:`datavalue_decoder`.
#     173
#     174 .. versionadded:: 0.3.0
#     175
#     176 """
#     177 decode = cast(Callable[[Client, str, Mapping[str, object]], object],
#     178               self.datavalue_decoder)
# --> 179 return decode(self, datatype, datavalue)
#
# File ~/anaconda3/lib/python3.11/site-packages/wikidata/datavalue.py:129, in Decoder.__call__(self, client, datatype, datavalue)
#     127 method = getattr(self, method_name, None)
#     128 if callable(method):
# --> 129     return method(client, datavalue)
#     130 raise DatavalueError('{!r} is unsupported type'.format(type_),
#     131                      datavalue)
#
# File ~/anaconda3/lib/python3.11/site-packages/wikidata/datavalue.py:167, in Decoder.time(self, client, datavalue)
#     165     raise DatavalueError('missing "calendarmodel" field', datavalue)
#     166 if cal != 'http://www.wikidata.org/entity/Q1985727':
# --> 167     raise DatavalueError('{!r} is unsupported calendarmodel for time '
#     168                          'datavalue'.format(cal), datavalue)
#     169 try:
#     170     time = value['time']
#
# DatavalueError: 'http://www.wikidata.org/entity/Q1985786' is unsupported calendarmodel for time datavalue: {'type': 'time', 'value': {'time': '+1551-09-19T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'}}

# %%
len(failed_codes)
# Out:
# 0

# %%
df_rank_2000_cleaned = df_rank_2000[df_rank_2000['date_of_birth'] != ""]

# %%
df_rank_2000_cleaned.shape
# Out:
# (1732, 50)

# %%
df_rank_2000_cleaned.to_sql('individuals_2000', engine)
# Out:
# 732
